# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
reviews[0].split(' ')
# Out:
# ['bromwell',
#  'high',
#  'is',
#  'a',
#  'cartoon',
#  'comedy',
#  '.',
#  'it',
#  'ran',
#  'at',
#  'the',
#  'same',
#  'time',
#  'as',
#  'some',
#  'other',
#  'programs',
#  'about',
#  'school',
#  'life',
#  '',
#  'such',
#  'as',
#  '',
#  'teachers',
#  '',
#  '.',
#  'my',
#  '',
#  '',
#  'years',
#  'in',
#  'the',
#  'teaching',
#  'profession',
#  'lead',
#  'me',
#  'to',
#  'believe',
#  'that',
#  'bromwell',
#  'high',
#  '',
#  's',
#  'satire',
#  'is',
#  'much',
#  'closer',
#  'to',
#  'reality',
#  'than',
#  'is',
#  '',
#  'teachers',
#  '',
#  '.',
#  'the',
#  'scramble',
#  'to',
#  'survive',
#  'financially',
#  '',
#  'the',
#  'insightful',
#  'students',
#  'who',
#  'can',
#  'see',
#  'right',
#  'through',
#  'their',
#  'pathetic',
#  'teachers',
#  '',
#  'pomp',
#  '',
#  'the',
#  'pettiness',
#  'of',
#  'the',
#  'whole',
#  'situation',
#  '',
#  'all',
#  'remind',
#  'me',
#  'of',
#  'the',
#  'schools',
#  'i',
#  'knew',
#  'and',
#  'their',
#  'students',
#  '.',
#  'when',
#  'i',
#  'saw',
#  'the',
#  'episode',
#  'in',
#  'which',
#  'a',
#  'student',
#  'repeatedly',
#  'tried',
#  'to',
#  'burn',
#  'down',
#  'the',
#  'school',
#  '',
#  'i',
#  'immediately',
#  'recalled',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'at',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'high',
#  '.',
#  'a',
#  'classic',
#  'line',
#  'inspector',
#  'i',
#  '',
#  'm',
#  'here',
#  'to',
#  'sack',
#  'one',
#  'of',
#  'your',
#  'teachers',
#  '.',
#  'student',
#  'welcome',
#  'to',
#  'bromwell',
#  'high',
#  '.',
#  'i',
#  'expect',
#  'that',
#  'many',
#  'adults',
#  'of',
#  'my',
#  'age',
#  'think',
#  'that',
#  'bromwell',
#  'high',
#  'is',
#  'far',
#  'fetched',
#  '.',
#  'what',
#  'a',
#  'pity',
#  'that',
#  'it',
#  'isn',
#  '',
#  't',
#  '',
#  '',
#  '']

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
for i in range(len(reviews)):
    dummy_counter = Counter(reviews[i].split(' '))
    if labels[i] == 'POSITIVE':
        positive_counts += dummy_counter
    else:
        negative_counts += dummy_counter
    total_counts += dummy_counter

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 582647),
#  ('the', 183689),
#  ('.', 168926),
#  ('and', 94859),
#  ('a', 88572),
#  ('of', 81433),
#  ('to', 70542),
#  ('is', 60470),
#  ('in', 53111),
#  ('br', 52233),
#  ('it', 50792),
#  ('i', 42965),
#  ('that', 37742),
#  ('this', 37130),
#  ('s', 35650),
#  ('as', 27823),
#  ('with', 24494),
#  ('for', 23664),
#  ('was', 23217),
#  ('film', 22181),
#  ('but', 21994),
#  ('movie', 20231),
#  ('his', 18118),
#  ('on', 17972),
#  ('you', 17583),
#  ('he', 17094),
#  ('are', 15731),
#  ('not', 15141),
#  ('t', 14490),
#  ('one', 14487),
#  ('have', 13328),
#  ('be', 13159),
#  ('by', 12664),
#  ('all', 12647),
#  ('who', 12144),
#  ('an', 11954),
#  ('at', 11884),
#  ('from', 11356),
#  ('her', 11103),
#  ('they', 10548),
#  ('has', 9743),
#  ('so', 9629),
#  ('like', 9571),
#  ('about', 8817),
#  ('very', 8785),
#  ('out', 8597),
#  ('there', 8508),
#  ('or', 8199),
#  ('she', 8184),
#  ('good', 8182),
#  ('what', 8180),
#  ('more', 7966),
#  ('when', 7866),
#  ('some', 7848),
#  ('if', 7694),
#  ('just', 7616),
#  ('can', 7380),
#  ('story', 7226),
#  ('time', 6908),
#  ('my', 6877),
#  ('great', 6796),
#  ('well', 6784),
#  ('up', 6651),
#  ('which', 6636),
#  ('their', 6482),
#  ('see', 6363),
#  ('we', 5895),
#  ('also', 5857),
#  ('really', 5743),
#  ('would', 5683),
#  ('will', 5500),
#  ('had', 5474),
#  ('only', 5436),
#  ('me', 5428),
#  ('him', 5290),
#  ('even', 5260),
#  ('other', 5173),
#  ('most', 5168),
#  ('were', 5135),
#  ('first', 5046),
#  ('than', 4985),
#  ('much', 4952),
#  ('its', 4874),
#  ('no', 4846),
#  ('into', 4808),
#  ('people', 4758),
#  ('love', 4597),
#  ('best', 4574),
#  ('get', 4514),
#  ('been', 4444),
#  ('how', 4436),
#  ('life', 4415),
#  ('because', 4330),
#  ('way', 4247),
#  ('do', 4158),
#  ('films', 4045),
#  ('made', 4042),
#  ('after', 4011),
#  ('them', 4006),
#  ('two', 3998),
#  ('many', 3964),
#  ('think', 3883),
#  ('too', 3880),
#  ('movies', 3818),
#  ('characters', 3794),
#  ('don', 3695),
#  ('character', 3695),
#  ('watch', 3642),
#  ('man', 3614),
#  ('show', 3611),
#  ('seen', 3608),
#  ('then', 3563),
#  ('little', 3551),
#  ('still', 3529),
#  ('make', 3465),
#  ('could', 3434),
#  ('never', 3430),
#  ('being', 3394),
#  ('where', 3356),
#  ('does', 3224),
#  ('over', 3207),
#  ('any', 3160),
#  ('while', 3060),
#  ('know', 2989),
#  ('did', 2945),
#  ('years', 2931),
#  ('ever', 2926),
#  ('here', 2904),
#  ('these', 2859),
#  ('end', 2835),
#  ('such', 2752),
#  ('scene', 2707),
#  ('real', 2704),
#  ('back', 2659),
#  ('though', 2627),
#  ('those', 2625),
#  ('world', 2601),
#  ('new', 2600),
#  ('off', 2597),
#  ('go', 2593),
#  ('acting', 2589),
#  ('your', 2577),
#  ('plot', 2567),
#  ('say', 2555),
#  ('scenes', 2549),
#  ('through', 2541),
#  ('better', 2541),
#  ('makes', 2527),
#  ('now', 2480),
#  ('young', 2461),
#  ('work', 2456),
#  ('ve', 2441),
#  ('old', 2429),
#  ('find', 2405),
#  ('both', 2393),
#  ('before', 2359),
#  ('series', 2307),
#  ('again', 2304),
#  ('quite', 2268),
#  ('should', 2267),
#  ('us', 2265),
#  ('cast', 2260),
#  ('something', 2256),
#  ('lot', 2229),
#  ('part', 2211),
#  ('always', 2204),
#  ('another', 2192),
#  ('actors', 2174),
#  ('director', 2144),
#  ('family', 2135),
#  ('own', 2131),
#  ('may', 2116),
#  ('between', 2115),
#  ('m', 2108),
#  ('same', 2086),
#  ('every', 2079),
#  ('funny', 2074),
#  ('role', 2072),
#  ('watching', 2071),
#  ('performance', 2045),
#  ('doesn', 2043),
#  ('bad', 2041),
#  ('few', 2039),
#  ('look', 2026),
#  ('re', 1973),
#  ('why', 1953),
#  ('things', 1943),
#  ('times', 1941),
#  ('big', 1914),
#  ('however', 1913),
#  ('actually', 1902),
#  ('going', 1887),
#  ('action', 1884),
#  ('bit', 1864),
#  ('must', 1841),
#  ('down', 1840),
#  ('comedy', 1838),
#  ('music', 1832),
#  ('right', 1811),
#  ('fact', 1802),
#  ('saw', 1798),
#  ('fun', 1798),
#  ('long', 1796),
#  ('take', 1793),
#  ('without', 1780),
#  ('excellent', 1777),
#  ('didn', 1770),
#  ('around', 1760),
#  ('thing', 1758),
#  ('each', 1745),
#  ('got', 1728),
#  ('thought', 1723),
#  ('feel', 1696),
#  ('day', 1694),
#  ('come', 1694),
#  ('done', 1690),
#  ('beautiful', 1686),
#  ('especially', 1673),
#  ('seems', 1672),
#  ('give', 1654),
#  ('played', 1654),
#  ('almost', 1652),
#  ('want', 1651),
#  ('pretty', 1642),
#  ('last', 1642),
#  ('yet', 1630),
#  ('since', 1612),
#  ('gets', 1597),
#  ('true', 1594),
#  ('different', 1590),
#  ('although', 1590),
#  ('interesting', 1577),
#  ('job', 1571),
#  ('enough', 1539),
#  ('woman', 1527),
#  ('our', 1524),
#  ('horror', 1519),
#  ('shows', 1510),
#  ('tv', 1482),
#  ('probably', 1478),
#  ('girl', 1471),
#  ('wonderful', 1464),
#  ('point', 1463),
#  ('plays', 1454),
#  ('original', 1454),
#  ('course', 1449),
#  ('father', 1442),
#  ('far', 1428),
#  ('nothing', 1426),
#  ('john', 1418),
#  ('rather', 1409),
#  ('ll', 1406),
#  ('dvd', 1403),
#  ('isn', 1398),
#  ('later', 1392),
#  ('d', 1392),
#  ('away', 1388),
#  ('war', 1386),
#  ('found', 1385),
#  ('whole', 1384),
#  ('screen', 1382),
#  ('once', 1379),
#  ('hard', 1376),
#  ('together', 1371),
#  ('year', 1363),
#  ('having', 1356),
#  ('set', 1352),
#  ('am', 1352),
#  ('place', 1337),
#  ('might', 1336),
#  ('comes', 1334),
#  ('making', 1332),
#  ('sure', 1332),
#  ('perfect', 1323),
#  ('play', 1318),
#  ('performances', 1318),
#  ('kind', 1316),
#  ('american', 1312),
#  ('worth', 1306),
#  ('takes', 1301),
#  ('three', 1296),
#  ('himself', 1291),
#  ('anyone', 1287),
#  ('everyone', 1283),
#  ('actor', 1272),
#  ('wife', 1263),
#  ('ending', 1261),
#  ('classic', 1246),
#  ('goes', 1242),
#  ('star', 1217),
#  ('version', 1213),
#  ('everything', 1207),
#  ('enjoy', 1206),
#  ('book', 1202),
#  ('house', 1200),
#  ('nice', 1190),
#  ('during', 1185),
#  ('seeing', 1177),
#  ('least', 1173),
#  ('put', 1170),
#  ('loved', 1164),
#  ('night', 1159),
#  ('watched', 1150),
#  ('high', 1148),
#  ('guy', 1148),
#  ('believe', 1146),
#  ('amazing', 1145),
#  ('top', 1135),
#  ('men', 1134),
#  ('anything', 1133),
#  ('hollywood', 1122),
#  ('definitely', 1115),
#  ('looking', 1113),
#  ('episode', 1112),
#  ('main', 1107),
#  ('special', 1100),
#  ('gives', 1098),
#  ('truly', 1082),
#  ('audience', 1082),
#  ('sense', 1081),
#  ('seem', 1080),
#  ('second', 1078),
#  ('fan', 1075),
#  ('home', 1071),
#  ('human', 1068),
#  ('mind', 1060),
#  ('recommend', 1059),
#  ('short', 1056),
#  ('small', 1055),
#  ('along', 1049),
#  ('help', 1048),
#  ('trying', 1045),
#  ('black', 1040),
#  ('full', 1039),
#  ('friends', 1038),
#  ('often', 1035),
#  ('script', 1029),
#  ('heart', 1029),
#  ('death', 1028),
#  ('said', 1028),
#  ('favorite', 1024),
#  ('until', 1020),
#  ('let', 1020),
#  ('remember', 1016),
#  ('left', 1012),
#  ('today', 1010),
#  ('less', 1001),
#  ('early', 1000),
#  ('live', 996),
#  ('maybe', 994),
#  ('moments', 988),
#  ('liked', 982),
#  ('others', 979),
#  ('become', 977),
#  ('brilliant', 975),
#  ('won', 974),
#  ('shot', 961),
#  ('looks', 955),
#  ('effects', 953),
#  ('used', 952),
#  ('cinema', 949),
#  ('came', 948),
#  ('lives', 944),
#  ('read', 942),
#  ('mother', 940),
#  ('highly', 939),
#  ('stars', 935),
#  ('style', 933),
#  ('boy', 931),
#  ('women', 931),
#  ('enjoyed', 931),
#  ('perhaps', 930),
#  ('given', 928),
#  ('drama', 922),
#  ('line', 918),
#  ('next', 911),
#  ('playing', 908),
#  ('entertaining', 908),
#  ('fine', 907),
#  ('need', 907),
#  ('use', 903),
#  ('mr', 901),
#  ('someone', 898),
#  ('kids', 895),
#  ('overall', 895),
#  ('simply', 892),
#  ('children', 890),
#  ('works', 884),
#  ('wasn', 883),
#  ('picture', 881),
#  ('keep', 879),
#  ('friend', 879),
#  ('minutes', 876),
#  ('certainly', 875),
#  ('dark', 874),
#  ('against', 873),
#  ('couple', 872),
#  ('face', 869),
#  ('finally', 867),
#  ('lost', 856),
#  ('history', 855),
#  ('michael', 855),
#  ('son', 854),
#  ('else', 844),
#  ('production', 843),
#  ('reason', 842),
#  ('understand', 842),
#  ('based', 840),
#  ('throughout', 839),
#  ('rest', 839),
#  ('several', 837),
#  ('fans', 836),
#  ('written', 833),
#  ('city', 826),
#  ('hope', 819),
#  ('strong', 818),
#  ('try', 818),
#  ('dead', 817),
#  ('white', 812),
#  ('school', 811),
#  ('tell', 808),
#  ('half', 805),
#  ('itself', 799),
#  ('start', 795),
#  ('game', 793),
#  ('idea', 792),
#  ('beginning', 789),
#  ('genre', 788),
#  ('person', 784),
#  ('case', 783),
#  ('sometimes', 782),
#  ('final', 781),
#  ('past', 780),
#  ('art', 778),
#  ('late', 773),
#  ('humor', 773),
#  ('yes', 771),
#  ('able', 770),
#  ('side', 769),
#  ('child', 769),
#  ('becomes', 767),
#  ('despite', 765),
#  ('town', 765),
#  ('money', 761),
#  ('completely', 758),
#  ('getting', 755),
#  ('stories', 754),
#  ('instead', 753),
#  ('camera', 751),
#  ('under', 743),
#  ('roles', 742),
#  ('soon', 742),
#  ('days', 735),
#  ('video', 735),
#  ('felt', 734),
#  ('viewer', 733),
#  ('simple', 731),
#  ('either', 726),
#  ('age', 722),
#  ('james', 722),
#  ('wrong', 717),
#  ('wants', 716),
#  ('doing', 716),
#  ('close', 711),
#  ('turns', 711),
#  ('name', 710),
#  ('episodes', 707),
#  ('title', 701),
#  ('evil', 699),
#  ('went', 699),
#  ('budget', 697),
#  ('piece', 695),
#  ('fantastic', 691),
#  ('relationship', 691),
#  ('called', 691),
#  ('david', 689),
#  ('turn', 684),
#  ('musical', 684),
#  ('direction', 681),
#  ('parts', 680),
#  ('head', 678),
#  ('eyes', 677),
#  ('absolutely', 676),
#  ('directed', 674),
#  ('sort', 672),
#  ('lead', 669),
#  ('actress', 669),
#  ('experience', 667),
#  ('oscar', 665),
#  ('sex', 665),
#  ('murder', 665),
#  ('jack', 664),
#  ('including', 662),
#  ('lines', 660),
#  ('brother', 660),
#  ('known', 658),
#  ('behind', 658),
#  ('example', 655),
#  ('feeling', 654),
#  ('chance', 652),
#  ('supporting', 650),
#  ('living', 650),
#  ('already', 648),
#  ('moment', 647),
#  ('score', 646),
#  ('low', 645),
#  ('voice', 644),
#  ('ago', 642),
#  ('themselves', 642),
#  ('dialogue', 641),
#  ('hit', 640),
#  ('matter', 639),
#  ('told', 638),
#  ('paul', 638),
#  ('hand', 636),
#  ('moving', 636),
#  ('romantic', 635),
#  ('quality', 634),
#  ('reality', 630),
#  ('entire', 630),
#  ('happy', 630),
#  ('hilarious', 630),
#  ('song', 629),
#  ('season', 627),
#  ('future', 626),
#  ('gave', 626),
#  ('police', 626),
#  ('light', 626),
#  ('enjoyable', 625),
#  ('number', 624),
#  ('released', 623),
#  ('finds', 621),
#  ('type', 617),
#  ('expect', 616),
#  ('sound', 614),
#  ('laugh', 613),
#  ('cinematography', 612),
#  ('husband', 612),
#  ('fight', 610),
#  ('king', 608),
#  ('whose', 608),
#  ('shown', 605),
#  ('particularly', 604),
#  ('daughter', 604),
#  ('took', 604),
#  ('coming', 599),
#  ('superb', 597),
#  ('view', 596),
#  ('leave', 595),
#  ('modern', 594),
#  ('english', 593),
#  ('documentary', 592),
#  ('important', 591),
#  ('mean', 591),
#  ('events', 590),
#  ('somewhat', 589),
#  ('miss', 588),
#  ('change', 587),
#  ('career', 587),
#  ('country', 587),
#  ('self', 587),
#  ('greatest', 586),
#  ('tells', 584),
#  ('run', 582),
#  ('girls', 581),
#  ('robert', 581),
#  ('heard', 580),
#  ('wanted', 579),
#  ('british', 578),
#  ('etc', 575),
#  ('totally', 572),
#  ('guys', 571),
#  ('tale', 570),
#  ('starts', 570),
#  ('care', 568),
#  ('usual', 567),
#  ('opinion', 566),
#  ('violence', 566),
#  ('easy', 562),
#  ('comic', 560),
#  ('thriller', 558),
#  ('says', 556),
#  ('animation', 556),
#  ('realistic', 552),
#  ('killer', 552),
#  ('act', 552),
#  ('ones', 552),
#  ('writer', 550),
#  ('writing', 550),
#  ('power', 549),
#  ('extremely', 549),
#  ('problem', 547),
#  ('television', 546),
#  ('songs', 544),
#  ('kid', 543),
#  ('novel', 538),
#  ('attention', 537),
#  ('involved', 537),
#  ('york', 536),
#  ('alone', 535),
#  ('hero', 535),
#  ('seemed', 534),
#  ('stuff', 533),
#  ('eye', 533),
#  ('god', 531),
#  ('wish', 530),
#  ('serious', 529),
#  ('french', 529),
#  ('kill', 528),
#  ('rock', 527),
#  ('taken', 525),
#  ('class', 524),
#  ('team', 519),
#  ('atmosphere', 518),
#  ('surprised', 517),
#  ('ways', 516),
#  ('sad', 516),
#  ('car', 516),
#  ('o', 516),
#  ('george', 515),
#  ('order', 514),
#  ('cool', 514),
#  ('richard', 514),
#  ('cannot', 513),
#  ('exactly', 513),
#  ('b', 513),
#  ('beauty', 512),
#  ('knows', 512),
#  ('begins', 512),
#  ('due', 511),
#  ('happened', 511),
#  ('similar', 511),
#  ('perfectly', 511),
#  ('sequence', 511),
#  ('among', 510),
#  ('across', 510),
#  ('powerful', 510),
#  ('taking', 510),
#  ('myself', 510),
#  ('room', 509),
#  ('theme', 509),
#  ('entertainment', 508),
#  ('anyway', 508),
#  ('famous', 508),
#  ('strange', 506),
#  ('tries', 506),
#  ('release', 505),
#  ('level', 505),
#  ('herself', 505),
#  ('four', 504),
#  ('happen', 503),
#  ('slow', 501),
#  ('opening', 501),
#  ('message', 501),
#  ('easily', 500),
#  ('problems', 499),
#  ('interest', 499),
#  ('society', 496),
#  ('unique', 496),
#  ('sets', 495),
#  ('memorable', 494),
#  ('ends', 494),
#  ('stop', 491),
#  ('brought', 491),
#  ('believable', 490),
#  ('mostly', 487),
#  ('red', 486),
#  ('upon', 485),
#  ('viewing', 485),
#  ('nature', 484),
#  ('thinking', 484),
#  ('romance', 484),
#  ('working', 483),
#  ('lady', 482),
#  ('crime', 482),
#  ('bring', 481),
#  ('sister', 481),
#  ('form', 480),
#  ('parents', 480),
#  ('dance', 480),
#  ('emotional', 479),
#  ('whether', 479),
#  ('knew', 478),
#  ('within', 478),
#  ('local', 478),
#  ('viewers', 478),
#  ('possible', 477),
#  ('happens', 476),
#  ('group', 476),
#  ('usually', 476),
#  ('couldn', 476),
#  ('meets', 473),
#  ('mystery', 473),
#  ('flick', 473),
#  ('peter', 472),
#  ('blood', 472),
#  ('certain', 471),
#  ('above', 470),
#  ('follow', 470),
#  ('major', 469),
#  ('soundtrack', 469),
#  ('middle', 469),
#  ('period', 466),
#  ('needs', 465),
#  ('killed', 464),
#  ('tom', 464),
#  ('th', 464),
#  ('disney', 463),
#  ('earth', 461),
#  ('typical', 460),
#  ('haven', 460),
#  ('de', 460),
#  ('feature', 459),
#  ('obviously', 458),
#  ('words', 456),
#  ('named', 456),
#  ('masterpiece', 455),
#  ('particular', 455),
#  ('stand', 454),
#  ('guess', 454),
#  ('fantasy', 454),
#  ('jane', 453),
#  ('elements', 452),
#  ('america', 452),
#  ('huge', 451),
#  ('stage', 448),
#  ('brings', 448),
#  ('yourself', 447),
#  ('fast', 447),
#  ('leads', 447),
#  ('started', 446),
#  ('showing', 445),
#  ('deal', 444),
#  ('poor', 442),
#  ('talent', 441),
#  ('running', 441),
#  ('indeed', 440),
#  ('personal', 439),
#  ('unfortunately', 439),
#  ('hours', 439),
#  ('japanese', 438),
#  ('street', 437),
#  ('incredible', 437),
#  ('sweet', 437),
#  ('deep', 435),
#  ('near', 434),
#  ('hour', 434),
#  ('truth', 433),
#  ('giving', 432),
#  ('nearly', 432),
#  ('obvious', 431),
#  ('female', 431),
#  ('rating', 431),
#  ('became', 431),
#  ('meet', 430),
#  ('turned', 430),
#  ('era', 429),
#  ('clearly', 427),
#  ('learn', 426),
#  ('cut', 425),
#  ('five', 425),
#  ('body', 425),
#  ('surprise', 425),
#  ('dream', 422),
#  ('talking', 420),
#  ('clear', 420),
#  ('note', 419),
#  ('eventually', 418),
#  ('except', 418),
#  ('means', 416),
#  ('fall', 415),
#  ('joe', 415),
#  ('feels', 415),
#  ('situation', 414),
#  ('comments', 414),
#  ('keeps', 414),
#  ('shots', 414),
#  ('lots', 414),
#  ('general', 413),
#  ('buy', 413),
#  ('complete', 412),
#  ('ten', 411),
#  ('match', 410),
#  ('unlike', 409),
#  ('present', 409),
#  ('older', 409),
#  ('william', 408),
#  ('filmed', 408),
#  ('difficult', 406),
#  ('gone', 405),
#  ('recommended', 404),
#  ('dramatic', 403),
#  ('appears', 403),
#  ('check', 403),
#  ('wonder', 402),
#  ('tony', 402),
#  ('third', 401),
#  ('subject', 401),
#  ('suspense', 400),
#  ('earlier', 400),
#  ('sequences', 398),
#  ('doubt', 397),
#  ('talk', 396),
#  ('beyond', 396),
#  ('portrayal', 395),
#  ('fi', 395),
#  ('baby', 395),
#  ('stewart', 394),
#  ('whom', 394),
#  ('points', 393),
#  ('plenty', 393),
#  ('sci', 393),
#  ('leaves', 392),
#  ('business', 392),
#  ('lee', 392),
#  ('hell', 391),
#  ('single', 391),
#  ('oh', 390),
#  ('beautifully', 390),
#  ('word', 389),
#  ('adventure', 388),
#  ('using', 387),
#  ('forget', 387),
#  ('add', 386),
#  ('falls', 386),
#  ('return', 385),
#  ('setting', 385),
#  ('married', 385),
#  ('scary', 384),
#  ('solid', 384),
#  ('battle', 384),
#  ('hear', 383),
#  ('lack', 383),
#  ('non', 382),
#  ('recently', 382),
#  ('figure', 382),
#  ('dog', 382),
#  ('touching', 381),
#  ('wouldn', 381),
#  ('jokes', 380),
#  ('bill', 380),
#  ('straight', 380),
#  ('awesome', 379),
#  ('success', 378),
#  ('boys', 378),
#  ('political', 378),
#  ('actual', 377),
#  ('outstanding', 377),
#  ('call', 377),
#  ('features', 377),
#  ('theater', 376),
#  ('sexual', 374),
#  ('terrific', 374),
#  ('sees', 374),
#  ('portrayed', 373),
#  ('please', 373),
#  ('social', 373),
#  ('move', 372),
#  ('brothers', 370),
#  ('leading', 369),
#  ('hate', 369),
#  ('rich', 368),
#  ('various', 368),
#  ('interested', 368),
#  ('dr', 368),
#  ('decent', 366),
#  ('space', 366),
#  ('mark', 366),
#  ('towards', 365),
#  ('screenplay', 364),
#  ('looked', 364),
#  ('aren', 364),
#  ('jim', 364),
#  ('die', 362),
#  ('animated', 362),
#  ('caught', 361),
#  ('western', 361),
#  ('none', 360),
#  ('directors', 360),
#  ('pace', 359),
#  ('disappointed', 358),
#  ('effective', 358),
#  ('acted', 358),
#  ('popular', 357),
#  ('boring', 357),
#  ('smith', 356),
#  ('charming', 356),
#  ('creepy', 355),
#  ('storyline', 355),
#  ('appreciate', 353),
#  ('intelligent', 353),
#  ('basically', 353),
#  ('manages', 353),
#  ('supposed', 352),
#  ('background', 352),
#  ('rare', 352),
#  ('open', 352),
#  ('subtle', 352),
#  ('impressive', 351),
#  ('journey', 351),
#  ('mention', 350),
#  ('spirit', 350),
#  ('moves', 349),
#  ('rate', 349),
#  ('century', 349),
#  ('familiar', 348),
#  ('realize', 347),
#  ('deserves', 347),
#  ('natural', 347),
#  ('noir', 347),
#  ('inside', 346),
#  ('mary', 346),
#  ('review', 345),
#  ('material', 345),
#  ('singing', 345),
#  ('pure', 344),
#  ('effect', 344),
#  ('ben', 343),
#  ('visual', 343),
#  ('cold', 343),
#  ('secret', 342),
#  ('office', 342),
#  ('magic', 342),
#  ('kelly', 342),
#  ('saying', 341),
#  ('created', 341),
#  ('question', 340),
#  ('language', 340),
#  ('hot', 340),
#  ('telling', 340),
#  ('harry', 340),
#  ('stunning', 339),
#  ('dancing', 339),
#  ('kept', 338),
#  ('somehow', 338),
#  ('reading', 336),
#  ('copy', 336),
#  ('create', 335),
#  ('seriously', 335),
#  ('imagine', 334),
#  ('free', 333),
#  ('uses', 333),
#  ('stay', 332),
#  ('scott', 332),
#  ('hands', 331),
#  ('escape', 331),
#  ('adult', 331),
#  ('complex', 331),
#  ('recent', 330),
#  ('plus', 330),
#  ('expected', 329),
#  ('average', 329),
#  ('wait', 329),
#  ('crazy', 329),
#  ('attempt', 328),
#  ('quickly', 328),
#  ('air', 328),
#  ('master', 327),
#  ('male', 327),
#  ('public', 327),
#  ('frank', 327),
#  ('filled', 325),
#  ('co', 324),
#  ('previous', 324),
#  ('apart', 324),
#  ('lovely', 324),
#  ('minute', 324),
#  ('ok', 324),
#  ('thanks', 323),
#  ('edge', 323),
#  ('following', 323),
#  ('surprisingly', 323),
#  ('e', 323),
#  ('successful', 322),
#  ('admit', 321),
#  ('german', 321),
#  ('reviews', 320),
#  ('touch', 320),
#  ('casting', 320),
#  ('exciting', 320),
#  ('studio', 320),
#  ('images', 319),
#  ('worked', 319),
#  ('outside', 319),
#  ('law', 319),
#  ('genius', 318),
#  ('laughs', 318),
#  ('follows', 317),
#  ('themes', 317),
#  ('reasons', 317),
#  ('fighting', 316),
#  ('break', 316),
#  ('slightly', 316),
#  ('weird', 316),
#  ('members', 315),
#  ('emotions', 315),
#  ('odd', 314),
#  ('needed', 314),
#  ('further', 313),
#  ('large', 313),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 593207),
#  ('.', 177315),
#  ('the', 172725),
#  ('a', 83816),
#  ('and', 78397),
#  ('to', 72866),
#  ('of', 72840),
#  ('br', 55703),
#  ('is', 52918),
#  ('it', 51038),
#  ('i', 49632),
#  ('in', 46147),
#  ('this', 43172),
#  ('that', 39765),
#  ('s', 33196),
#  ('was', 27739),
#  ('movie', 26435),
#  ('for', 23109),
#  ('but', 22964),
#  ('with', 22039),
#  ('as', 21790),
#  ('t', 21533),
#  ('film', 20234),
#  ('you', 18527),
#  ('on', 18161),
#  ('not', 17309),
#  ('have', 16001),
#  ('are', 15497),
#  ('be', 15382),
#  ('he', 14554),
#  ('one', 13885),
#  ('they', 13858),
#  ('at', 12959),
#  ('his', 12776),
#  ('all', 12755),
#  ('so', 12159),
#  ('like', 11869),
#  ('there', 11326),
#  ('just', 11170),
#  ('by', 11155),
#  ('an', 10862),
#  ('or', 10839),
#  ('who', 10524),
#  ('from', 10314),
#  ('if', 10047),
#  ('about', 9562),
#  ('out', 9465),
#  ('what', 8904),
#  ('some', 8733),
#  ('no', 8598),
#  ('her', 8368),
#  ('even', 8129),
#  ('can', 8090),
#  ('has', 8016),
#  ('good', 7864),
#  ('bad', 7852),
#  ('would', 7471),
#  ('up', 7333),
#  ('only', 7185),
#  ('when', 7121),
#  ('more', 7100),
#  ('she', 6749),
#  ('really', 6604),
#  ('time', 6585),
#  ('had', 6495),
#  ('my', 6375),
#  ('were', 6362),
#  ('which', 6090),
#  ('very', 6089),
#  ('me', 5910),
#  ('see', 5764),
#  ('don', 5618),
#  ('we', 5618),
#  ('their', 5580),
#  ('do', 5528),
#  ('story', 5489),
#  ('than', 5451),
#  ('been', 5368),
#  ('much', 5366),
#  ('get', 5307),
#  ('because', 5246),
#  ('people', 5055),
#  ('then', 5014),
#  ('make', 4996),
#  ('how', 4979),
#  ('could', 4932),
#  ('any', 4929),
#  ('into', 4815),
#  ('made', 4783),
#  ('first', 4575),
#  ('well', 4514),
#  ('other', 4503),
#  ('them', 4432),
#  ('too', 4403),
#  ('plot', 4392),
#  ('movies', 4295),
#  ('acting', 4294),
#  ('will', 4267),
#  ('way', 4223),
#  ('most', 4128),
#  ('after', 4066),
#  ('him', 4059),
#  ('its', 3879),
#  ('think', 3864),
#  ('characters', 3795),
#  ('also', 3775),
#  ('off', 3765),
#  ('watch', 3751),
#  ('did', 3740),
#  ('why', 3679),
#  ('character', 3663),
#  ('being', 3582),
#  ('better', 3552),
#  ('know', 3518),
#  ('over', 3506),
#  ('seen', 3468),
#  ('never', 3449),
#  ('ever', 3439),
#  ('where', 3436),
#  ('your', 3413),
#  ('two', 3334),
#  ('little', 3276),
#  ('films', 3258),
#  ('m', 3188),
#  ('here', 3187),
#  ('nothing', 3163),
#  ('say', 3147),
#  ('end', 3108),
#  ('should', 3088),
#  ('many', 3086),
#  ('something', 3072),
#  ('show', 3050),
#  ('does', 3032),
#  ('thing', 3028),
#  ('ve', 2988),
#  ('scene', 2987),
#  ('scenes', 2970),
#  ('these', 2925),
#  ('go', 2884),
#  ('didn', 2809),
#  ('great', 2791),
#  ('re', 2779),
#  ('watching', 2775),
#  ('doesn', 2752),
#  ('through', 2692),
#  ('such', 2686),
#  ('worst', 2623),
#  ('man', 2619),
#  ('actors', 2594),
#  ('while', 2578),
#  ('actually', 2570),
#  ('back', 2562),
#  ('director', 2548),
#  ('life', 2544),
#  ('going', 2458),
#  ('funny', 2457),
#  ('still', 2405),
#  ('now', 2389),
#  ('look', 2381),
#  ('another', 2371),
#  ('those', 2350),
#  ('old', 2343),
#  ('real', 2297),
#  ('horror', 2283),
#  ('few', 2282),
#  ('before', 2263),
#  ('minutes', 2261),
#  ('want', 2255),
#  ('love', 2245),
#  ('pretty', 2243),
#  ('same', 2225),
#  ('best', 2210),
#  ('though', 2199),
#  ('script', 2179),
#  ('every', 2146),
#  ('work', 2144),
#  ('least', 2111),
#  ('seems', 2110),
#  ('down', 2096),
#  ('enough', 2094),
#  ('guy', 2072),
#  ('original', 2061),
#  ('got', 2059),
#  ('around', 2051),
#  ('part', 2044),
#  ('lot', 1991),
#  ('anything', 1980),
#  ('find', 1973),
#  ('things', 1966),
#  ('new', 1960),
#  ('again', 1952),
#  ('fact', 1951),
#  ('isn', 1950),
#  ('point', 1950),
#  ('give', 1946),
#  ('makes', 1919),
#  ('take', 1910),
#  ('thought', 1903),
#  ('d', 1886),
#  ('years', 1867),
#  ('whole', 1853),
#  ('long', 1850),
#  ('however', 1841),
#  ('making', 1800),
#  ('cast', 1798),
#  ('gets', 1795),
#  ('big', 1763),
#  ('might', 1755),
#  ('money', 1731),
#  ('interesting', 1723),
#  ('far', 1719),
#  ('action', 1717),
#  ('right', 1715),
#  ('us', 1708),
#  ('without', 1698),
#  ('come', 1691),
#  ('ll', 1677),
#  ('quite', 1669),
#  ('almost', 1663),
#  ('awful', 1642),
#  ('kind', 1634),
#  ('reason', 1624),
#  ('must', 1617),
#  ('done', 1612),
#  ('looks', 1607),
#  ('am', 1603),
#  ('wasn', 1573),
#  ('boring', 1572),
#  ('instead', 1572),
#  ('comedy', 1571),
#  ('poor', 1570),
#  ('someone', 1570),
#  ('trying', 1568),
#  ('saw', 1558),
#  ('away', 1553),
#  ('probably', 1530),
#  ('believe', 1528),
#  ('girl', 1526),
#  ('sure', 1510),
#  ('looking', 1500),
#  ('world', 1495),
#  ('maybe', 1493),
#  ('stupid', 1491),
#  ('anyone', 1490),
#  ('since', 1488),
#  ('last', 1474),
#  ('terrible', 1474),
#  ('times', 1467),
#  ('rather', 1465),
#  ('tv', 1464),
#  ('may', 1462),
#  ('let', 1461),
#  ('hard', 1452),
#  ('between', 1450),
#  ('woman', 1440),
#  ('waste', 1436),
#  ('feel', 1423),
#  ('effects', 1419),
#  ('half', 1407),
#  ('own', 1406),
#  ('young', 1404),
#  ('music', 1396),
#  ('idea', 1389),
#  ('book', 1380),
#  ('sense', 1377),
#  ('bit', 1361),
#  ('series', 1355),
#  ('having', 1353),
#  ('found', 1329),
#  ('put', 1327),
#  ('goes', 1325),
#  ('worse', 1318),
#  ('said', 1311),
#  ('role', 1308),
#  ('comes', 1287),
#  ('everything', 1273),
#  ('main', 1269),
#  ('screen', 1265),
#  ('else', 1265),
#  ('budget', 1260),
#  ('low', 1259),
#  ('audience', 1252),
#  ('either', 1252),
#  ('yet', 1250),
#  ('actor', 1250),
#  ('ending', 1250),
#  ('family', 1241),
#  ('supposed', 1239),
#  ('completely', 1236),
#  ('set', 1235),
#  ('both', 1229),
#  ('always', 1228),
#  ('left', 1226),
#  ('wrong', 1225),
#  ('seem', 1219),
#  ('course', 1207),
#  ('watched', 1207),
#  ('place', 1205),
#  ('shot', 1194),
#  ('simply', 1192),
#  ('day', 1183),
#  ('mean', 1176),
#  ('special', 1165),
#  ('house', 1162),
#  ('read', 1153),
#  ('three', 1147),
#  ('oh', 1145),
#  ('year', 1143),
#  ('dead', 1141),
#  ('high', 1131),
#  ('less', 1126),
#  ('camera', 1124),
#  ('worth', 1123),
#  ('our', 1119),
#  ('night', 1119),
#  ('horrible', 1115),
#  ('once', 1110),
#  ('try', 1109),
#  ('black', 1101),
#  ('couldn', 1097),
#  ('although', 1095),
#  ('video', 1093),
#  ('line', 1082),
#  ('rest', 1077),
#  ('sex', 1076),
#  ('played', 1073),
#  ('fun', 1071),
#  ('dvd', 1070),
#  ('production', 1068),
#  ('everyone', 1060),
#  ('mind', 1055),
#  ('seeing', 1054),
#  ('during', 1053),
#  ('american', 1043),
#  ('play', 1039),
#  ('kids', 1039),
#  ('version', 1034),
#  ('given', 1027),
#  ('used', 1025),
#  ('tell', 1024),
#  ('second', 1022),
#  ('women', 1021),
#  ('together', 1016),
#  ('performance', 1010),
#  ('takes', 1004),
#  ('especially', 1003),
#  ('need', 1003),
#  ('wife', 1002),
#  ('use', 998),
#  ('start', 998),
#  ('dialogue', 994),
#  ('each', 990),
#  ('star', 989),
#  ('problem', 986),
#  ('unfortunately', 985),
#  ('doing', 985),
#  ('fan', 972),
#  ('lines', 970),
#  ('killer', 970),
#  ('himself', 968),
#  ('couple', 967),
#  ('crap', 967),
#  ('getting', 962),
#  ('name', 960),
#  ('help', 959),
#  ('death', 958),
#  ('piece', 942),
#  ('guess', 941),
#  ('head', 935),
#  ('different', 927),
#  ('entire', 923),
#  ('later', 921),
#  ('nice', 919),
#  ('short', 914),
#  ('school', 913),
#  ('seemed', 912),
#  ('next', 909),
#  ('shows', 908),
#  ('john', 900),
#  ('hollywood', 898),
#  ('home', 895),
#  ('sort', 890),
#  ('absolutely', 887),
#  ('understand', 886),
#  ('person', 886),
#  ('true', 883),
#  ('felt', 878),
#  ('care', 875),
#  ('plays', 874),
#  ('written', 873),
#  ('decent', 869),
#  ('until', 868),
#  ('flick', 866),
#  ('title', 865),
#  ('men', 861),
#  ('job', 858),
#  ('stars', 856),
#  ('face', 854),
#  ('friends', 851),
#  ('went', 850),
#  ('yes', 850),
#  ('called', 849),
#  ('case', 847),
#  ('itself', 847),
#  ('along', 842),
#  ('perhaps', 842),
#  ('writing', 834),
#  ('annoying', 830),
#  ('wanted', 830),
#  ('top', 830),
#  ('full', 828),
#  ('hour', 827),
#  ('ridiculous', 827),
#  ('evil', 826),
#  ('came', 824),
#  ('tries', 824),
#  ('guys', 812),
#  ('laugh', 809),
#  ('totally', 809),
#  ('won', 808),
#  ('keep', 805),
#  ('god', 803),
#  ('playing', 801),
#  ('already', 799),
#  ('direction', 796),
#  ('example', 787),
#  ('save', 787),
#  ('gore', 785),
#  ('attempt', 784),
#  ('obviously', 784),
#  ('lost', 782),
#  ('sound', 779),
#  ('act', 779),
#  ('war', 779),
#  ('thinking', 777),
#  ('except', 777),
#  ('car', 775),
#  ('kill', 775),
#  ('b', 767),
#  ('ok', 764),
#  ('white', 764),
#  ('truly', 763),
#  ('moments', 759),
#  ('remember', 758),
#  ('finally', 758),
#  ('blood', 757),
#  ('father', 753),
#  ('style', 751),
#  ('turn', 751),
#  ('cheap', 739),
#  ('lack', 736),
#  ('wouldn', 736),
#  ('please', 734),
#  ('quality', 730),
#  ('dull', 725),
#  ('starts', 718),
#  ('boy', 718),
#  ('seriously', 717),
#  ('run', 716),
#  ('recommend', 716),
#  ('none', 715),
#  ('kid', 713),
#  ('looked', 712),
#  ('enjoy', 712),
#  ('lead', 712),
#  ('girls', 710),
#  ('children', 710),
#  ('under', 709),
#  ('stuff', 707),
#  ('beginning', 707),
#  ('hope', 706),
#  ('hell', 705),
#  ('episode', 702),
#  ('etc', 700),
#  ('slow', 698),
#  ('against', 698),
#  ('myself', 697),
#  ('obvious', 696),
#  ('wonder', 695),
#  ('small', 695),
#  ('hand', 694),
#  ('behind', 693),
#  ('killed', 693),
#  ('others', 692),
#  ('lame', 690),
#  ('poorly', 686),
#  ('complete', 684),
#  ('picture', 681),
#  ('avoid', 678),
#  ('fans', 678),
#  ('anyway', 677),
#  ('mother', 675),
#  ('apparently', 675),
#  ('based', 675),
#  ('cut', 674),
#  ('early', 674),
#  ('happens', 673),
#  ('writer', 673),
#  ('despite', 672),
#  ('becomes', 671),
#  ('classic', 670),
#  ('become', 669),
#  ('predictable', 668),
#  ('several', 668),
#  ('certainly', 664),
#  ('live', 664),
#  ('self', 663),
#  ('often', 663),
#  ('gave', 662),
#  ('close', 660),
#  ('cannot', 660),
#  ('stop', 654),
#  ('silly', 652),
#  ('saying', 651),
#  ('scary', 647),
#  ('mr', 641),
#  ('overall', 637),
#  ('friend', 637),
#  ('liked', 636),
#  ('jokes', 636),
#  ('wants', 635),
#  ('expect', 632),
#  ('child', 631),
#  ('happened', 630),
#  ('human', 628),
#  ('bunch', 625),
#  ('entertaining', 625),
#  ('cinema', 625),
#  ('beautiful', 623),
#  ('final', 622),
#  ('daughter', 619),
#  ('performances', 617),
#  ('eyes', 617),
#  ('says', 615),
#  ('themselves', 613),
#  ('fight', 611),
#  ('actress', 607),
#  ('badly', 606),
#  ('turns', 605),
#  ('days', 605),
#  ('directed', 604),
#  ('disappointed', 604),
#  ('interest', 603),
#  ('group', 603),
#  ('call', 602),
#  ('happen', 602),
#  ('involved', 601),
#  ('hours', 601),
#  ('shots', 600),
#  ('humor', 600),
#  ('body', 599),
#  ('running', 598),
#  ('basically', 597),
#  ('sorry', 596),
#  ('heard', 596),
#  ('art', 594),
#  ('viewer', 593),
#  ('talking', 592),
#  ('violence', 590),
#  ('yourself', 588),
#  ('side', 588),
#  ('extremely', 586),
#  ('throughout', 585),
#  ('gives', 583),
#  ('rating', 583),
#  ('hero', 583),
#  ('possible', 581),
#  ('word', 581),
#  ('single', 580),
#  ('started', 580),
#  ('mess', 579),
#  ('leave', 579),
#  ('alone', 577),
#  ('type', 576),
#  ('dark', 575),
#  ('weak', 574),
#  ('parts', 572),
#  ('game', 571),
#  ('michael', 569),
#  ('unless', 568),
#  ('review', 568),
#  ('effort', 566),
#  ('definitely', 566),
#  ('able', 566),
#  ('took', 565),
#  ('female', 565),
#  ('son', 563),
#  ('voice', 563),
#  ('aren', 562),
#  ('zombie', 562),
#  ('non', 561),
#  ('drama', 561),
#  ('turned', 559),
#  ('matter', 559),
#  ('usually', 559),
#  ('exactly', 558),
#  ('town', 558),
#  ('five', 554),
#  ('past', 551),
#  ('sequel', 550),
#  ('huge', 550),
#  ('soon', 548),
#  ('police', 547),
#  ('middle', 545),
#  ('tried', 545),
#  ('feeling', 542),
#  ('earth', 542),
#  ('talent', 542),
#  ('cool', 541),
#  ('genre', 540),
#  ('ends', 537),
#  ('serious', 535),
#  ('history', 534),
#  ('straight', 532),
#  ('major', 529),
#  ('opening', 528),
#  ('sad', 528),
#  ('beyond', 527),
#  ('coming', 526),
#  ('dialog', 524),
#  ('moment', 524),
#  ('particularly', 519),
#  ('taken', 518),
#  ('wasted', 518),
#  ('premise', 518),
#  ('level', 516),
#  ('clearly', 516),
#  ('lives', 514),
#  ('rent', 514),
#  ('fast', 511),
#  ('across', 511),
#  ('okay', 508),
#  ('joke', 508),
#  ('minute', 508),
#  ('dumb', 508),
#  ('editing', 507),
#  ('mostly', 506),
#  ('mention', 506),
#  ('stories', 506),
#  ('talk', 505),
#  ('falls', 505),
#  ('theater', 504),
#  ('fails', 501),
#  ('stay', 500),
#  ('hit', 498),
#  ('late', 495),
#  ('pointless', 492),
#  ('order', 489),
#  ('storyline', 489),
#  ('die', 489),
#  ('write', 487),
#  ('sometimes', 486),
#  ('whatever', 485),
#  ('taking', 484),
#  ('wish', 484),
#  ('fine', 484),
#  ('known', 482),
#  ('words', 482),
#  ('career', 481),
#  ('sit', 480),
#  ('room', 480),
#  ('appears', 480),
#  ('english', 479),
#  ('ten', 477),
#  ('lee', 475),
#  ('told', 475),
#  ('chance', 475),
#  ('power', 473),
#  ('monster', 473),
#  ('husband', 472),
#  ('brother', 471),
#  ('living', 471),
#  ('novel', 470),
#  ('somehow', 468),
#  ('killing', 467),
#  ('imdb', 466),
#  ('add', 464),
#  ('using', 464),
#  ('ones', 464),
#  ('total', 463),
#  ('murder', 461),
#  ('strange', 460),
#  ('actual', 460),
#  ('giving', 460),
#  ('shown', 459),
#  ('four', 459),
#  ('material', 458),
#  ('points', 457),
#  ('hate', 457),
#  ('problems', 453),
#  ('king', 453),
#  ('works', 453),
#  ('kept', 453),
#  ('opinion', 452),
#  ('possibly', 452),
#  ('including', 450),
#  ('knew', 450),
#  ('easily', 450),
#  ('number', 449),
#  ('usual', 448),
#  ('nudity', 447),
#  ('age', 447),
#  ('local', 446),
#  ('due', 445),
#  ('reviews', 445),
#  ('experience', 443),
#  ('imagine', 443),
#  ('roles', 443),
#  ('ago', 442),
#  ('flat', 442),
#  ('near', 441),
#  ('decided', 441),
#  ('writers', 438),
#  ('class', 438),
#  ('feels', 438),
#  ('space', 438),
#  ('zombies', 436),
#  ('change', 435),
#  ('city', 435),
#  ('score', 434),
#  ('cheesy', 434),
#  ('somewhat', 434),
#  ('plain', 432),
#  ('song', 432),
#  ('otherwise', 431),
#  ('whether', 431),
#  ('shame', 430),
#  ('bring', 430),
#  ('cinematography', 428),
#  ('wait', 428),
#  ('nor', 427),
#  ('needs', 426),
#  ('credits', 425),
#  ('nearly', 425),
#  ('knows', 425),
#  ('upon', 425),
#  ('pathetic', 424),
#  ('songs', 423),
#  ('whose', 423),
#  ('released', 423),
#  ('lots', 422),
#  ('expected', 421),
#  ('entertainment', 421),
#  ('footage', 420),
#  ('doubt', 420),
#  ('james', 419),
#  ('comments', 419),
#  ('average', 418),
#  ('free', 417),
#  ('lady', 416),
#  ('cop', 415),
#  ('sets', 415),
#  ('excellent', 414),
#  ('bored', 412),
#  ('attention', 412),
#  ('needed', 410),
#  ('figure', 410),
#  ('view', 409),
#  ('o', 409),
#  ('laughable', 409),
#  ('sequence', 408),
#  ('clear', 406),
#  ('check', 406),
#  ('general', 405),
#  ('light', 405),
#  ('stand', 405),
#  ('forced', 405),
#  ('documentary', 405),
#  ('george', 404),
#  ('development', 404),
#  ('potential', 404),
#  ('ask', 403),
#  ('garbage', 403),
#  ('comic', 402),
#  ('david', 402),
#  ('mystery', 402),
#  ('within', 402),
#  ('robert', 401),
#  ('above', 401),
#  ('television', 399),
#  ('musical', 399),
#  ('buy', 399),
#  ('country', 398),
#  ('means', 397),
#  ('hot', 397),
#  ('important', 397),
#  ('thriller', 396),
#  ('trash', 396),
#  ('begin', 396),
#  ('gone', 395),
#  ('reality', 395),
#  ('fall', 394),
#  ('forward', 394),
#  ('move', 394),
#  ('happy', 392),
#  ('directing', 392),
#  ('reading', 391),
#  ('heart', 390),
#  ('gay', 390),
#  ('haven', 390),
#  ('incredibly', 389),
#  ('eye', 389),
#  ('hear', 389),
#  ('sounds', 389),
#  ('message', 388),
#  ('enjoyed', 387),
#  ('weird', 387),
#  ('hardly', 387),
#  ('spent', 387),
#  ('filmed', 387),
#  ('remake', 387),
#  ('suspense', 386),
#  ('forget', 386),
#  ('male', 386),
#  ('hilarious', 385),
#  ('sadly', 385),
#  ('box', 384),
#  ('third', 383),
#  ('british', 383),
#  ('fake', 382),
#  ('laughs', 381),
#  ('pay', 381),
#  ('named', 381),
#  ('failed', 377),
#  ('rock', 377),
#  ('perfect', 377),
#  ('showing', 377),
#  ('comment', 376),
#  ('cover', 376),
#  ('miss', 375),
#  ('sequences', 375),
#  ('sister', 375),
#  ('question', 374),
#  ('events', 372),
#  ('finds', 371),
#  ('feature', 371),
#  ('similar', 371),
#  ('attempts', 370),
#  ('tom', 370),
#  ('screenplay', 369),
#  ('crazy', 368),
#  ('brain', 368),
#  ('elements', 368),
#  ('modern', 368),
#  ('girlfriend', 367),
#  ('filmmakers', 367),
#  ('spoilers', 367),
#  ('ideas', 366),
#  ('directors', 366),
#  ('neither', 366),
#  ('loved', 365),
#  ('result', 365),
#  ('sexual', 364),
#  ('richard', 363),
#  ('air', 362),
#  ('typical', 362),
#  ('worked', 360),
#  ('excuse', 360),
#  ('red', 359),
#  ('fire', 358),
#  ('working', 358),
#  ('barely', 357),
#  ('producers', 357),
#  ('team', 357),
#  ('theme', 356),
#  ('unbelievable', 356),
#  ('dr', 356),
#  ('baby', 355),
#  ('wrote', 355),
#  ('appear', 355),
#  ('christmas', 355),
#  ('tells', 354),
#  ('follow', 354),
#  ('viewers', 353),
#  ('leads', 353),
#  ('strong', 352),
#  ('open', 352),
#  ('meant', 352),
#  ('slasher', 351),
#  ('eventually', 350),
#  ('nowhere', 350),
#  ('gun', 350),
#  ('island', 349),
#  ('disappointing', 349),
#  ('van', 349),
#  ('plus', 348),
#  ('twist', 347),
#  ('weren', 347),
#  ('acted', 347),
#  ('admit', 347),
#  ('quickly', 345),
#  ('makers', 344),
#  ('villain', 344),
#  ('list', 344),
#  ('herself', 344),
#  ('kills', 344),
#  ('honestly', 344),
#  ('positive', 343),
#  ('apart', 343),
#  ('realize', 342),
#  ('walk', 342),
#  ('period', 341),
#  ('release', 341),
#  ('e', 340),
#  ('yeah', 340),
#  ('subject', 339),
#  ('stick', 339),
#  ('bother', 339),
#  ('doctor', 339),
#  ('hands', 338),
#  ('concept', 337),
#  ('dog', 337),
#  ('learn', 336),
#  ('japanese', 336),
#  ('peter', 336),
#  ('simple', 335),
#  ('note', 335),
#  ('casting', 335),
#  ('f', 334),
#  ('missing', 334),
#  ('fi', 334),
#  ('expecting', 334),
#  ('previous', 334),
#  ('disappointment', 334),
#  ('future', 333),
#  ('grade', 332),
#  ('shoot', 332),
#  ('value', 332),
#  ('certain', 331),
#  ('sci', 331),
#  ('suddenly', 330),
#  ('break', 328),
#  ('painful', 327),
#  ('form', 327),
#  ('ways', 327),
#  ('surprise', 327),
#  ('soundtrack', 327),
#  ('jack', 326),
#  ('front', 326),
#  ('project', 326),
#  ('somewhere', 326),
#  ('leaves', 325),
#  ('begins', 325),
#  ('ended', 325),
#  ('th', 325),
#  ('parents', 323),
#  ('surprised', 323),
#  ('c', 323),
#  ('difficult', 323),
#  ('effect', 322),
#  ('today', 322),
#  ('truth', 321),
#  ('street', 321),
#  ('biggest', 320),
#  ('accent', 319),
#  ('spend', 319),
#  ('redeeming', 319),
#  ('computer', 319),
#  ('creepy', 318),
#  ('crew', 317),
#  ('utterly', 317),
#  ('rate', 317),
#  ('america', 317),
#  ('indeed', 317),
#  ('relationship', 317),
#  ('deal', 315),
#  ('fighting', 315),
#  ('among', 315),
#  ('bottom', 314),
#  ('episodes', 314),
#  ('disney', 314),
#  ('situation', 313),
#  ('york', 312),
#  ('outside', 312),
#  ('create', 311),
#  ('considering', 311),
#  ('vampire', 311),
#  ('co', 310),
#  ('joe', 309),
#  ('talented', 309),
#  ('towards', 309),
#  ('speak', 309),
#  ('interested', 309),
#  ('became', 308),
#  ('cause', 308),
#  ('naked', 307),
#  ('fairly', 307),
#  ('revenge', 307),
#  ('earlier', 306),
#  ('paul', 306),
#  ('cartoon', 306),
#  ('reasons', 305),
#  ('wonderful', 305),
#  ('channel', 305),
#  ('college', 305),
#  ('basic', 304),
#  ('mediocre', 304),
#  ('telling', 304),
#  ('stage', 304),
#  ('credit', 303),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times
for word, count in positive_counts.items():
    pos_neg_ratios += Counter({ word: count/ float(negative_counts[word] + 1) })

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0634704676771303
# Pos-to-neg ratio for 'amazing' = 4.089285714285714
# Pos-to-neg ratio for 'terrible' = 0.1783050847457627

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs
d = {}
for word, value in pos_neg_ratios.items():
    d[word] = np.log(value)
pos_neg_ratios = Counter(d)

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.06153758628070421
# Pos-to-neg ratio for 'amazing' = 1.4083703128190905
# Pos-to-neg ratio for 'terrible' = -1.7242592365961558

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 4.6913478822291435),
#  ('antwone', 4.477336814478207),
#  ('din', 4.406719247264253),
#  ('caruso', 4.30406509320417),
#  ('ahmad', 4.2626798770413155),
#  ('gunga', 4.189654742026425),
#  ('goldsworthy', 4.174387269895637),
#  ('sabu', 4.1588830833596715),
#  ('jaffar', 4.127134385045092),
#  ('gypo', 4.0943445622221),
#  ('yokai', 4.0943445622221),
#  ('paulie', 4.07753744390572),
#  ('pimlico', 3.9889840465642745),
#  ('visconti', 3.9318256327243257),
#  ('flavia', 3.9318256327243257),
#  ('blandings', 3.871201010907891),
#  ('kells', 3.871201010907891),
#  ('brashear', 3.8501476017100584),
#  ('gino', 3.828641396489095),
#  ('deathtrap', 3.8066624897703196),
#  ('tsui', 3.713572066704308),
#  ('lindy', 3.713572066704308),
#  ('harilal', 3.713572066704308),
#  ('panahi', 3.713572066704308),
#  ('ossessione', 3.6635616461296463),
#  ('khouri', 3.58351893845611),
#  ('dominick', 3.58351893845611),
#  ('aweigh', 3.5553480614894135),
#  ('mj', 3.5553480614894135),
#  ('mcintire', 3.5263605246161616),
#  ('kriemhild', 3.5263605246161616),
#  ('blackie', 3.4965075614664802),
#  ('daisies', 3.4965075614664802),
#  ('newcombe', 3.4965075614664802),
#  ('delpy', 3.4657359027997265),
#  ('kei', 3.4657359027997265),
#  ('trelkovsky', 3.4657359027997265),
#  ('miklos', 3.4339872044851463),
#  ('hilliard', 3.4339872044851463),
#  ('gundam', 3.4231762883809305),
#  ('uld', 3.4011973816621555),
#  ('egon', 3.4011973816621555),
#  ('coulouris', 3.4011973816621555),
#  ('bathsheba', 3.4011973816621555),
#  ('pazu', 3.4011973816621555),
#  ('sheeta', 3.4011973816621555),
#  ('krell', 3.4011973816621555),
#  ('offside', 3.4011973816621555),
#  ('paine', 3.367295829986474),
#  ('hewlett', 3.367295829986474),
#  ('venoms', 3.367295829986474),
#  ('fineman', 3.367295829986474),
#  ('duprez', 3.332204510175204),
#  ('ranma', 3.332204510175204),
#  ('ronny', 3.332204510175204),
#  ('kipling', 3.295836866004329),
#  ('ingram', 3.295836866004329),
#  ('abhay', 3.295836866004329),
#  ('pym', 3.258096538021482),
#  ('quibble', 3.2188758248682006),
#  ('abu', 3.2188758248682006),
#  ('gabe', 3.2188758248682006),
#  ('audiard', 3.2188758248682006),
#  ('kelso', 3.2188758248682006),
#  ('milverton', 3.2188758248682006),
#  ('scalise', 3.2188758248682006),
#  ('felix', 3.1780538303479458),
#  ('giovanna', 3.1780538303479458),
#  ('grisby', 3.1780538303479458),
#  ('mukhsin', 3.1780538303479458),
#  ('xica', 3.1780538303479458),
#  ('moonwalker', 3.1780538303479458),
#  ('feinstone', 3.1780538303479458),
#  ('pidgeon', 3.1354942159291497),
#  ('chikatilo', 3.1354942159291497),
#  ('togar', 3.1354942159291497),
#  ('heaton', 3.1354942159291497),
#  ('jannings', 3.1354942159291497),
#  ('luzhin', 3.1135153092103742),
#  ('firemen', 3.091042453358316),
#  ('nandini', 3.091042453358316),
#  ('rf', 3.091042453358316),
#  ('prologues', 3.091042453358316),
#  ('soha', 3.091042453358316),
#  ('matuschek', 3.091042453358316),
#  ('leonora', 3.091042453358316),
#  ('desdemona', 3.091042453358316),
#  ('fanfan', 3.091042453358316),
#  ('matador', 3.091042453358316),
#  ('philo', 3.068052935133617),
#  ('korda', 3.060270794691562),
#  ('versatility', 3.044522437723423),
#  ('holloway', 3.044522437723423),
#  ('joss', 3.044522437723423),
#  ('microfilm', 3.044522437723423),
#  ('maradona', 3.044522437723423),
#  ('reda', 3.044522437723423),
#  ('gauri', 3.044522437723423),
#  ('bjm', 3.044522437723423),
#  ('excellently', 3.0122615755052013),
#  ('capote', 3.0122615755052013),
#  ('fido', 3.0081547935525483),
#  ('ori', 2.995732273553991),
#  ('wilhelm', 2.995732273553991),
#  ('chamberlains', 2.995732273553991),
#  ('bowser', 2.995732273553991),
#  ('knockout', 2.995732273553991),
#  ('emory', 2.995732273553991),
#  ('carrre', 2.995732273553991),
#  ('prote', 2.995732273553991),
#  ('coe', 2.995732273553991),
#  ('mcintyre', 2.995732273553991),
#  ('siegfried', 2.995732273553991),
#  ('coonskin', 2.995732273553991),
#  ('clutter', 2.970414465569701),
#  ('cannavale', 2.9444389791664403),
#  ('deanna', 2.9444389791664403),
#  ('rozsa', 2.9444389791664403),
#  ('anchors', 2.9444389791664403),
#  ('digicorp', 2.9444389791664403),
#  ('malfique', 2.9444389791664403),
#  ('schlesinger', 2.9444389791664403),
#  ('magnus', 2.9444389791664403),
#  ('burakov', 2.9444389791664403),
#  ('ackland', 2.9444389791664403),
#  ('rvd', 2.9444389791664403),
#  ('baloo', 2.9444389791664403),
#  ('hillyer', 2.9444389791664403),
#  ('ferdie', 2.9444389791664403),
#  ('pakeezah', 2.9444389791664403),
#  ('petiot', 2.9444389791664403),
#  ('pinjar', 2.9444389791664403),
#  ('flippen', 2.9444389791664403),
#  ('railly', 2.9444389791664403),
#  ('kolchak', 2.9311937524164198),
#  ('hayworth', 2.9267394020670396),
#  ('tatsuhito', 2.8903717578961645),
#  ('natali', 2.8903717578961645),
#  ('falco', 2.8903717578961645),
#  ('lando', 2.8903717578961645),
#  ('iphigenia', 2.8903717578961645),
#  ('pappas', 2.8903717578961645),
#  ('guerrero', 2.8903717578961645),
#  ('burgade', 2.8903717578961645),
#  ('iek', 2.8903717578961645),
#  ('hobson', 2.8903717578961645),
#  ('geer', 2.8903717578961645),
#  ('pollak', 2.8903717578961645),
#  ('volckman', 2.8903717578961645),
#  ('hoechlin', 2.8903717578961645),
#  ('sammo', 2.8716796248840124),
#  ('iturbi', 2.8716796248840124),
#  ('naudet', 2.833213344056216),
#  ('nighy', 2.833213344056216),
#  ('toughness', 2.833213344056216),
#  ('sox', 2.833213344056216),
#  ('orked', 2.833213344056216),
#  ('kralik', 2.833213344056216),
#  ('nagra', 2.833213344056216),
#  ('jeon', 2.833213344056216),
#  ('laputa', 2.833213344056216),
#  ('jacknife', 2.833213344056216),
#  ('peralta', 2.833213344056216),
#  ('biko', 2.833213344056216),
#  ('beckett', 2.833213344056216),
#  ('callahan', 2.833213344056216),
#  ('cdric', 2.833213344056216),
#  ('polanski', 2.8233610476132043),
#  ('alvin', 2.8183982582710754),
#  ('matthau', 2.80672172860924),
#  ('celine', 2.803360380906535),
#  ('abbey', 2.803360380906535),
#  ('aiello', 2.803360380906535),
#  ('harriet', 2.7880929087757464),
#  ('bromwell', 2.772588722239781),
#  ('stettner', 2.772588722239781),
#  ('lian', 2.772588722239781),
#  ('smita', 2.772588722239781),
#  ('nihalani', 2.772588722239781),
#  ('shinjuku', 2.772588722239781),
#  ('apophis', 2.772588722239781),
#  ('oro', 2.772588722239781),
#  ('bake', 2.772588722239781),
#  ('verger', 2.772588722239781),
#  ('basra', 2.772588722239781),
#  ('linklater', 2.772588722239781),
#  ('footlight', 2.772588722239781),
#  ('treaty', 2.772588722239781),
#  ('mathieu', 2.772588722239781),
#  ('firefighter', 2.772588722239781),
#  ('macready', 2.772588722239781),
#  ('janos', 2.772588722239781),
#  ('santos', 2.772588722239781),
#  ('duffell', 2.772588722239781),
#  ('natalia', 2.772588722239781),
#  ('bombshells', 2.772588722239781),
#  ('hulce', 2.772588722239781),
#  ('gaiman', 2.772588722239781),
#  ('yvaine', 2.772588722239781),
#  ('bedknobs', 2.772588722239781),
#  ('endor', 2.772588722239781),
#  ('rotj', 2.772588722239781),
#  ('antz', 2.772588722239781),
#  ('adele', 2.751535313041949),
#  ('gackt', 2.751535313041949),
#  ('gilliam', 2.740840023925201),
#  ('chamberlain', 2.7300291078209855),
#  ('vance', 2.7212954278522306),
#  ('cynics', 2.70805020110221),
#  ('shetty', 2.70805020110221),
#  ('goa', 2.70805020110221),
#  ('grot', 2.70805020110221),
#  ('patekar', 2.70805020110221),
#  ('intricately', 2.70805020110221),
#  ('malleson', 2.70805020110221),
#  ('johnnie', 2.70805020110221),
#  ('baton', 2.70805020110221),
#  ('cheh', 2.70805020110221),
#  ('valette', 2.70805020110221),
#  ('gunbuster', 2.70805020110221),
#  ('mcanally', 2.70805020110221),
#  ('calamai', 2.70805020110221),
#  ('hickock', 2.70805020110221),
#  ('doktor', 2.70805020110221),
#  ('schildkraut', 2.70805020110221),
#  ('aviv', 2.70805020110221),
#  ('rotoscoped', 2.70805020110221),
#  ('hilda', 2.70805020110221),
#  ('cognac', 2.70805020110221),
#  ('lanisha', 2.70805020110221),
#  ('soutendijk', 2.70805020110221),
#  ('kiley', 2.70805020110221),
#  ('shintaro', 2.70805020110221),
#  ('ashraf', 2.70805020110221),
#  ('silberling', 2.70805020110221),
#  ('ballantine', 2.70805020110221),
#  ('gannon', 2.70805020110221),
#  ('eustache', 2.70805020110221),
#  ('karas', 2.70805020110221),
#  ('parador', 2.70805020110221),
#  ('goines', 2.70805020110221),
#  ('grasshoppers', 2.70805020110221),
#  ('burman', 2.70805020110221),
#  ('partition', 2.6741486494265287),
#  ('conroy', 2.6741486494265287),
#  ('chavez', 2.667228206581955),
#  ('ratso', 2.653241964607215),
#  ('aro', 2.6390573296152584),
#  ('xu', 2.6390573296152584),
#  ('patil', 2.6390573296152584),
#  ('vizier', 2.6390573296152584),
#  ('solvang', 2.6390573296152584),
#  ('melancholic', 2.6390573296152584),
#  ('embezzler', 2.6390573296152584),
#  ('fetisov', 2.6390573296152584),
#  ('cb', 2.6390573296152584),
#  ('pilgrimage', 2.6390573296152584),
#  ('tulip', 2.6390573296152584),
#  ('rien', 2.6390573296152584),
#  ('gardenia', 2.6390573296152584),
#  ('gialli', 2.6390573296152584),
#  ('ishwar', 2.6390573296152584),
#  ('cartwrights', 2.6390573296152584),
#  ('emy', 2.6390573296152584),
#  ('danelia', 2.6390573296152584),
#  ('scrat', 2.6390573296152584),
#  ('beek', 2.6390573296152584),
#  ('kabei', 2.6390573296152584),
#  ('laine', 2.6390573296152584),
#  ('atoz', 2.6390573296152584),
#  ('megs', 2.6390573296152584),
#  ('kulkarni', 2.6390573296152584),
#  ('bathhouse', 2.6390573296152584),
#  ('pang', 2.6390573296152584),
#  ('hickam', 2.6390573296152584),
#  ('ultimatum', 2.6210388241125804),
#  ('northam', 2.6100697927420065),
#  ('sg', 2.6026896854443837),
#  ('woronov', 2.6026896854443837),
#  ('mildred', 2.6026896854443837),
#  ('fricker', 2.6026896854443837),
#  ('emil', 2.6026896854443837),
#  ('katsu', 2.6026896854443837),
#  ('dev', 2.6026896854443837),
#  ('cal', 2.580216829592325),
#  ('victoria', 2.569464037816063),
#  ('zhu', 2.5649493574615367),
#  ('sadashiv', 2.5649493574615367),
#  ('amrapurkar', 2.5649493574615367),
#  ('zu', 2.5649493574615367),
#  ('unpretentious', 2.5649493574615367),
#  ('tissues', 2.5649493574615367),
#  ('odysseus', 2.5649493574615367),
#  ('bouvier', 2.5649493574615367),
#  ('luchino', 2.5649493574615367),
#  ('girotti', 2.5649493574615367),
#  ('mclaglen', 2.5649493574615367),
#  ('choi', 2.5649493574615367),
#  ('brownstone', 2.5649493574615367),
#  ('riget', 2.5649493574615367),
#  ('unsung', 2.5649493574615367),
#  ('autograph', 2.5649493574615367),
#  ('sugiyama', 2.5649493574615367),
#  ('chavo', 2.5649493574615367),
#  ('saura', 2.5649493574615367),
#  ('mcdoakes', 2.5649493574615367),
#  ('dola', 2.5649493574615367),
#  ('broadbent', 2.5649493574615367),
#  ('goring', 2.5649493574615367),
#  ('adjani', 2.5649493574615367),
#  ('boop', 2.5649493574615367),
#  ('freebird', 2.5649493574615367),
#  ('eglantine', 2.5649493574615367),
#  ('oakie', 2.5649493574615367),
#  ('gabriella', 2.5649493574615367),
#  ('guadalcanal', 2.5649493574615367),
#  ('yelnats', 2.5649493574615367),
#  ('nibelungen', 2.5649493574615367),
#  ('sputnik', 2.5649493574615367),
#  ('bahrain', 2.5649493574615367),
#  ('erendira', 2.5649493574615367),
#  ('gandhi', 2.538973871058276),
#  ('sammi', 2.538973871058276),
#  ('warhols', 2.538973871058276),
#  ('sirk', 2.531426665422893),
#  ('sunrise', 2.531426665422893),
#  ('flawless', 2.5257286443082556),
#  ('rosenstrasse', 2.512305623976115),
#  ('bernsen', 2.505525936990736),
#  ('creasy', 2.505525936990736),
#  ('kazan', 2.501435951739211),
#  ('braveheart', 2.501435951739211),
#  ('reservations', 2.4849066497880004),
#  ('concubine', 2.4849066497880004),
#  ('browder', 2.4849066497880004),
#  ('anand', 2.4849066497880004),
#  ('ardh', 2.4849066497880004),
#  ('transports', 2.4849066497880004),
#  ('radiant', 2.4849066497880004),
#  ('crouse', 2.4849066497880004),
#  ('hayter', 2.4849066497880004),
#  ('blyth', 2.4849066497880004),
#  ('unparalleled', 2.4849066497880004),
#  ('viennese', 2.4849066497880004),
#  ('strindberg', 2.4849066497880004),
#  ('holodeck', 2.4849066497880004),
#  ('hanlon', 2.4849066497880004),
#  ('natures', 2.4849066497880004),
#  ('lassalle', 2.4849066497880004),
#  ('cacoyannis', 2.4849066497880004),
#  ('euripides', 2.4849066497880004),
#  ('hecht', 2.4849066497880004),
#  ('luger', 2.4849066497880004),
#  ('bouzaglo', 2.4849066497880004),
#  ('mcadam', 2.4849066497880004),
#  ('lupino', 2.4849066497880004),
#  ('bischoff', 2.4849066497880004),
#  ('herge', 2.4849066497880004),
#  ('anselmo', 2.4849066497880004),
#  ('bressart', 2.4849066497880004),
#  ('talos', 2.4849066497880004),
#  ('clutters', 2.4849066497880004),
#  ('perdition', 2.4849066497880004),
#  ('parminder', 2.4849066497880004),
#  ('santiago', 2.4849066497880004),
#  ('yeon', 2.4849066497880004),
#  ('vierde', 2.4849066497880004),
#  ('hayao', 2.4849066497880004),
#  ('barrister', 2.4849066497880004),
#  ('lafitte', 2.4849066497880004),
#  ('blackadder', 2.4849066497880004),
#  ('binder', 2.4849066497880004),
#  ('killian', 2.4849066497880004),
#  ('trenholm', 2.4849066497880004),
#  ('gallico', 2.4849066497880004),
#  ('attila', 2.4849066497880004),
#  ('mcphillip', 2.4849066497880004),
#  ('yuzna', 2.4849066497880004),
#  ('balduin', 2.4849066497880004),
#  ('poonam', 2.4849066497880004),
#  ('rideau', 2.4849066497880004),
#  ('presque', 2.4849066497880004),
#  ('vonnegut', 2.463853240590168),
#  ('myrtle', 2.463853240590168),
#  ('othello', 2.46080909820894),
#  ('mccoy', 2.456735772821304),
#  ('taker', 2.456735772821304),
#  ('jonestown', 2.4423470353692043),
#  ('godmother', 2.4423470353692043),
#  ('mahatma', 2.4423470353692043),
#  ('mcnally', 2.4423470353692043),
#  ('durbin', 2.4277482359480516),
#  ('fuller', 2.423537703411708),
#  ('elsa', 2.4203681286504293),
#  ('christy', 2.4203681286504293),
#  ('cheadle', 2.4159137783010487),
#  ('calvet', 2.3978952727983707),
#  ('johnston', 2.3978952727983707),
#  ('separating', 2.3978952727983707),
#  ('hardworking', 2.3978952727983707),
#  ('hermione', 2.3978952727983707),
#  ('lassick', 2.3978952727983707),
#  ('spacecamp', 2.3978952727983707),
#  ('eisenhower', 2.3978952727983707),
#  ('faultless', 2.3978952727983707),
#  ('lok', 2.3978952727983707),
#  ('unsurpassed', 2.3978952727983707),
#  ('thursby', 2.3978952727983707),
#  ('filone', 2.3978952727983707),
#  ('ramones', 2.3978952727983707),
#  ('eminent', 2.3978952727983707),
#  ('soapdish', 2.3978952727983707),
#  ('seine', 2.3978952727983707),
#  ('taoist', 2.3978952727983707),
#  ('huns', 2.3978952727983707),
#  ('cookbook', 2.3978952727983707),
#  ('waterman', 2.3978952727983707),
#  ('sweetin', 2.3978952727983707),
#  ('nord', 2.3978952727983707),
#  ('showings', 2.3978952727983707),
#  ('bazza', 2.3978952727983707),
#  ('yasmin', 2.3978952727983707),
#  ('stitzer', 2.3978952727983707),
#  ('dorsey', 2.3978952727983707),
#  ('fanshawe', 2.3978952727983707),
#  ('pike', 2.3978952727983707),
#  ('tykwer', 2.3978952727983707),
#  ('hoss', 2.3978952727983707),
#  ('dorfman', 2.3978952727983707),
#  ('sjoman', 2.3978952727983707),
#  ('antonietta', 2.3978952727983707),
#  ('faust', 2.3978952727983707),
#  ('arrondissement', 2.3978952727983707),
#  ('hanka', 2.3978952727983707),
#  ('muska', 2.3978952727983707),
#  ('tetsur', 2.3978952727983707),
#  ('stockwell', 2.3978952727983707),
#  ('gorris', 2.3978952727983707),
#  ('fellowes', 2.3978952727983707),
#  ('regent', 2.3978952727983707),
#  ('bartel', 2.3978952727983707),
#  ('pei', 2.3978952727983707),
#  ('zp', 2.3978952727983707),
#  ('nyqvist', 2.3978952727983707),
#  ('leaud', 2.3978952727983707),
#  ('dragoon', 2.3978952727983707),
#  ('gracia', 2.3978952727983707),
#  ('bruhl', 2.3978952727983707),
#  ('bolan', 2.3978952727983707),
#  ('starewicz', 2.3978952727983707),
#  ('atul', 2.3978952727983707),
#  ('capano', 2.3978952727983707),
#  ('vadar', 2.3978952727983707),
#  ('gundams', 2.3978952727983707),
#  ('hallen', 2.3978952727983707),
#  ('shep', 2.3978952727983707),
#  ('rawhide', 2.3978952727983707),
#  ('bagdad', 2.379546134130174),
#  ('busby', 2.367123614131617),
#  ('pita', 2.367123614131617),
#  ('corbett', 2.367123614131617),
#  ('sweetly', 2.3513752571634776),
#  ('lucile', 2.3513752571634776),
#  ('brisson', 2.3513752571634776),
#  ('schmid', 2.3513752571634776),
#  ('oberon', 2.3513752571634776),
#  ('marylee', 2.3513752571634776),
#  ('winchester', 2.3353749158170367),
#  ('jabba', 2.327277705584417),
#  ('delightfully', 2.322387720290225),
#  ('armistead', 2.302585092994046),
#  ('daniell', 2.302585092994046),
#  ('wang', 2.302585092994046),
#  ('bianlian', 2.302585092994046),
#  ('velankar', 2.302585092994046),
#  ('boundless', 2.302585092994046),
#  ('gouald', 2.302585092994046),
#  ('euthanasia', 2.302585092994046),
#  ('shanks', 2.302585092994046),
#  ('asgard', 2.302585092994046),
#  ('axel', 2.302585092994046),
#  ('beery', 2.302585092994046),
#  ('vernacular', 2.302585092994046),
#  ('forged', 2.302585092994046),
#  ('ould', 2.302585092994046),
#  ('loners', 2.302585092994046),
#  ('kelada', 2.302585092994046),
#  ('herr', 2.302585092994046),
#  ('djinn', 2.302585092994046),
#  ('arias', 2.302585092994046),
#  ('rheostatics', 2.302585092994046),
#  ('phyllida', 2.302585092994046),
#  ('stevenson', 2.302585092994046),
#  ('alta', 2.302585092994046),
#  ('novak', 2.302585092994046),
#  ('quebec', 2.302585092994046),
#  ('rea', 2.302585092994046),
#  ('yam', 2.302585092994046),
#  ('beale', 2.302585092994046),
#  ('pquerette', 2.302585092994046),
#  ('virile', 2.302585092994046),
#  ('jud', 2.302585092994046),
#  ('rollicking', 2.302585092994046),
#  ('wuhl', 2.302585092994046),
#  ('apatow', 2.302585092994046),
#  ('margo', 2.302585092994046),
#  ('montrose', 2.302585092994046),
#  ('ungar', 2.302585092994046),
#  ('haines', 2.302585092994046),
#  ('arzenta', 2.302585092994046),
#  ('manny', 2.302585092994046),
#  ('ref', 2.302585092994046),
#  ('rhapsody', 2.302585092994046),
#  ('levitt', 2.302585092994046),
#  ('strombel', 2.302585092994046),
#  ('kidd', 2.302585092994046),
#  ('strickland', 2.302585092994046),
#  ('waterloo', 2.302585092994046),
#  ('bannister', 2.302585092994046),
#  ('broinowski', 2.302585092994046),
#  ('floraine', 2.302585092994046),
#  ('waxworks', 2.302585092994046),
#  ('ernesto', 2.302585092994046),
#  ('athens', 2.302585092994046),
#  ('ankush', 2.302585092994046),
#  ('colman', 2.302585092994046),
#  ('katey', 2.302585092994046),
#  ('sikes', 2.302585092994046),
#  ('restoring', 2.302585092994046),
#  ('parkins', 2.302585092994046),
#  ('mariner', 2.302585092994046),
#  ('hickcock', 2.302585092994046),
#  ('fps', 2.302585092994046),
#  ('coop', 2.302585092994046),
#  ('topher', 2.302585092994046),
#  ('tollinger', 2.302585092994046),
#  ('overpopulation', 2.302585092994046),
#  ('ghibli', 2.302585092994046),
#  ('girlfight', 2.302585092994046),
#  ('rudyard', 2.302585092994046),
#  ('tigerland', 2.302585092994046),
#  ('gwizdo', 2.302585092994046),
#  ('milyang', 2.302585092994046),
#  ('flamenco', 2.302585092994046),
#  ('hisaishi', 2.302585092994046),
#  ('maetel', 2.302585092994046),
#  ('pasdar', 2.302585092994046),
#  ('tam', 2.302585092994046),
#  ('philipps', 2.302585092994046),
#  ('pneumonic', 2.302585092994046),
#  ('poldi', 2.302585092994046),
#  ('hemo', 2.302585092994046),
#  ('swashbucklers', 2.302585092994046),
#  ('manfred', 2.302585092994046),
#  ('gervais', 2.302585092994046),
#  ('portobello', 2.302585092994046),
#  ('hundstage', 2.302585092994046),
#  ('spanky', 2.302585092994046),
#  ('gilberte', 2.302585092994046),
#  ('randell', 2.302585092994046),
#  ('trnka', 2.302585092994046),
#  ('jermaine', 2.302585092994046),
#  ('homeward', 2.302585092994046),
#  ('miou', 2.302585092994046),
#  ('prag', 2.302585092994046),
#  ('zechs', 2.302585092994046),
#  ('ginty', 2.302585092994046),
#  ('lifshitz', 2.302585092994046),
#  ('thornway', 2.302585092994046),
#  ('keeler', 2.2857779746776643),
#  ('carla', 2.277267285009756),
#  ('fagin', 2.277267285009756),
#  ('hanzo', 2.277267285009756),
#  ('aunts', 2.268683541318364),
#  ('olympia', 2.268683541318364),
#  ('sullavan', 2.268683541318364),
#  ('dench', 2.268683541318364),
#  ('sabrina', 2.264363880173848),
#  ('finely', 2.2512917986064953),
#  ('sailing', 2.2512917986064953),
#  ('treasured', 2.2512917986064953),
#  ('province', 2.2512917986064953),
#  ('peters', 2.2512917986064953),
#  ('zentropa', 2.2512917986064953),
#  ('mccartney', 2.2512917986064953),
#  ('gigi', 2.2512917986064953),
#  ('hickok', 2.2512917986064953),
#  ('tully', 2.2512917986064953),
#  ('beetle', 2.2512917986064953),
#  ('elia', 2.2512917986064953),
#  ('aborigines', 2.2512917986064953),
#  ('enchanting', 2.2407096892759584),
#  ('mostel', 2.2407096892759584),
#  ('superbly', 2.23907168727172),
#  ('complement', 2.2335922215070942),
#  ('tomlinson', 2.2335922215070942),
#  ('tenant', 2.228477120840324),
#  ('vertigo', 2.224623551524334),
#  ('influential', 2.224623551524334),
#  ('kalifornia', 2.224623551524334),
#  ('stardust', 2.2192034840549946),
#  ('kinnear', 2.2155737160044158),
#  ('rukh', 2.209494669928034),
#  ('zhou', 2.1972245773362196),
#  ('intimidated', 2.1972245773362196),
#  ('malone', 2.1972245773362196),
#  ('awsome', 2.1972245773362196),
#  ('versailles', 2.1972245773362196),
#  ('touchingly', 2.1972245773362196),
#  ('abbot', 2.1972245773362196),
#  ('culver', 2.1972245773362196),
#  ('thrive', 2.1972245773362196),
#  ('georges', 2.1972245773362196),
#  ('rca', 2.1972245773362196),
#  ('pemberton', 2.1972245773362196),
#  ('coulardeau', 2.1972245773362196),
#  ('squire', 2.1972245773362196),
#  ('imperioli', 2.1972245773362196),
#  ('marchand', 2.1972245773362196),
#  ('faceted', 2.1972245773362196),
#  ('giuseppe', 2.1972245773362196),
#  ('futures', 2.1972245773362196),
#  ('bizet', 2.1972245773362196),
#  ('hatcher', 2.1972245773362196),
#  ('montmartre', 2.1972245773362196),
#  ('managers', 2.1972245773362196),
#  ('doubtlessly', 2.1972245773362196),
#  ('qualifying', 2.1972245773362196),
#  ('cruiserweight', 2.1972245773362196),
#  ('salazar', 2.1972245773362196),
#  ('jeffs', 2.1972245773362196),
#  ('guignol', 2.1972245773362196),
#  ('lawton', 2.1972245773362196),
#  ('raines', 2.1972245773362196),
#  ('hazlehurst', 2.1972245773362196),
#  ('ferland', 2.1972245773362196),
#  ('madhubala', 2.1972245773362196),
#  ('omnibus', 2.1972245773362196),
#  ('frulein', 2.1972245773362196),
#  ('torrens', 2.1972245773362196),
#  ('gespenster', 2.1972245773362196),
#  ('proust', 2.1972245773362196),
#  ('louella', 2.1972245773362196),
#  ('peepers', 2.1972245773362196),
#  ('romantics', 2.1972245773362196),
#  ('mes', 2.1972245773362196),
#  ('hom', 2.1972245773362196),
#  ('benet', 2.1972245773362196),
#  ('timone', 2.1972245773362196),
#  ('hickory', 2.1972245773362196),
#  ('vue', 2.1972245773362196),
#  ('informant', 2.1972245773362196),
#  ('peretti', 2.1972245773362196),
#  ('luque', 2.1972245773362196),
#  ('szifron', 2.1972245773362196),
#  ('lata', 2.1972245773362196),
#  ('dumbrille', 2.1972245773362196),
#  ('quartier', 2.1972245773362196),
#  ('faubourg', 2.1972245773362196),
#  ('tuileries', 2.1972245773362196),
#  ('bte', 2.1972245773362196),
#  ('kleinman', 2.1972245773362196),
#  ('sumpter', 2.1972245773362196),
#  ('livesey', 2.1972245773362196),
#  ('lago', 2.1972245773362196),
#  ('macchesney', 2.1972245773362196),
#  ('machaty', 2.1972245773362196),
#  ('scarwid', 2.1972245773362196),
#  ('maxx', 2.1972245773362196),
#  ('cassio', 2.1972245773362196),
#  ('stig', 2.1972245773362196),
#  ('lebrun', 2.1972245773362196),
#  ('feroz', 2.1972245773362196),
#  ('gulpilil', 2.1972245773362196),
#  ('sachar', 2.1972245773362196),
#  ('tronje', 2.1972245773362196),
#  ('nwh', 2.1972245773362196),
#  ('grayce', 2.1972245773362196),
#  ('brimmer', 2.1972245773362196),
#  ('pedicab', 2.1972245773362196),
#  ('banjos', 2.1972245773362196),
#  ('dickey', 2.1972245773362196),
#  ('devotion', 2.174751721484161),
#  ('abby', 2.169053700369523),
#  ('hark', 2.169053700369523),
#  ('cheung', 2.169053700369523),
#  ('doggie', 2.159484249353372),
#  ('marvelously', 2.159484249353372),
#  ('iris', 2.159484249353372),
#  ('weir', 2.159484249353372),
#  ('perfection', 2.1546649629174235),
#  ('hawke', 2.151762203259462),
#  ('travers', 2.1400661634962708),
#  ('dearly', 2.1400661634962708),
#  ('mores', 2.1400661634962708),
#  ('nan', 2.1400661634962708),
#  ('leung', 2.1400661634962708),
#  ('spellbinding', 2.1400661634962708),
#  ('brodie', 2.1400661634962708),
#  ('mahoney', 2.1400661634962708),
#  ('dixon', 2.1400661634962708),
#  ('kennel', 2.1400661634962708),
#  ('speakeasy', 2.1400661634962708),
#  ('pressburger', 2.1400661634962708),
#  ('curr', 2.1400661634962708),
#  ('trier', 2.1316272948504063),
#  ('pecker', 2.128231705849268),
#  ('blondell', 2.12525107771113),
#  ('miyazaki', 2.120263536200091),
#  ('wodehouse', 2.120263536200091),
#  ('transcends', 2.1102132003465894),
#  ('darius', 2.1102132003465894),
#  ('astaire', 2.0959708436310462),
#  ('observant', 2.0794415416798357),
#  ('logand', 2.0794415416798357),
#  ('tolbukhin', 2.0794415416798357),
#  ('lovett', 2.0794415416798357),
#  ('dewitt', 2.0794415416798357),
#  ('bukater', 2.0794415416798357),
#  ('overhyped', 2.0794415416798357),
#  ('beguiling', 2.0794415416798357),
#  ('renying', 2.0794415416798357),
#  ('sichuan', 2.0794415416798357),
#  ('conceptions', 2.0794415416798357),
#  ('buaku', 2.0794415416798357),
#  ('offon', 2.0794415416798357),
#  ('hackett', 2.0794415416798357),
#  ('govind', 2.0794415416798357),
#  ('sgc', 2.0794415416798357),
#  ('rda', 2.0794415416798357),
#  ('coupons', 2.0794415416798357),
#  ('ida', 2.0794415416798357),
#  ('unheralded', 2.0794415416798357),
#  ('gianfranco', 2.0794415416798357),
#  ('lotus', 2.0794415416798357),
#  ('milton', 2.0794415416798357),
#  ('frills', 2.0794415416798357),
#  ('richness', 2.0794415416798357),
#  ('abydos', 2.0794415416798357),
#  ('dirtiest', 2.0794415416798357),
#  ('geoff', 2.0794415416798357),
#  ('pom', 2.0794415416798357),
#  ('fdr', 2.0794415416798357),
#  ('teck', 2.0794415416798357),
#  ('brancovis', 2.0794415416798357),
#  ('muller', 2.0794415416798357),
#  ('wastrel', 2.0794415416798357),
#  ('beulah', 2.0794415416798357),
#  ('bondi', 2.0794415416798357),
#  ('personifies', 2.0794415416798357),
#  ('mimics', 2.0794415416798357),
#  ('burgundians', 2.0794415416798357),
#  ('sweltering', 2.0794415416798357),
#  ('vinson', 2.0794415416798357),
#  ('goldoni', 2.0794415416798357),
#  ('heartbreakingly', 2.0794415416798357),
#  ('inaccessible', 2.0794415416798357),
#  ('tieh', 2.0794415416798357),
#  ('yang', 2.0794415416798357),
#  ('revere', 2.0794415416798357),
#  ('forge', 2.0794415416798357),
#  ('gainax', 2.0794415416798357),
#  ('tackled', 2.0794415416798357),
#  ('bragana', 2.0794415416798357),
#  ('rostov', 2.0794415416798357),
#  ('meyerling', 2.0794415416798357),
#  ('saks', 2.0794415416798357),
#  ('pleasence', 2.0794415416798357),
#  ('romy', 2.0794415416798357),
#  ('amplified', 2.0794415416798357),
#  ('cristy', 2.0794415416798357),
#  ('bakersfield', 2.0794415416798357),
#  ('benoit', 2.0794415416798357),
#  ('sharpshooter', 2.0794415416798357),
#  ('boothe', 2.0794415416798357),
#  ('tingler', 2.0794415416798357),
#  ('johanson', 2.0794415416798357),
#  ('unafraid', 2.0794415416798357),
#  ('dimaggio', 2.0794415416798357),
#  ('ashura', 2.0794415416798357),
#  ('braun', 2.0794415416798357),
#  ('herg', 2.0794415416798357),
#  ('trampa', 2.0794415416798357),
#  ('yin', 2.0794415416798357),
#  ('cinematographers', 2.0794415416798357),
#  ('windmill', 2.0794415416798357),
#  ('yamamoto', 2.0794415416798357),
#  ('technicolour', 2.0794415416798357),
#  ('captivates', 2.0794415416798357),
#  ('mathis', 2.0794415416798357),
#  ('jodelle', 2.0794415416798357),
#  ('disarming', 2.0794415416798357),
#  ('nyree', 2.0794415416798357),
#  ('bedchamber', 2.0794415416798357),
#  ('devos', 2.0794415416798357),
#  ('munshi', 2.0794415416798357),
#  ('hennessy', 2.0794415416798357),
#  ('sagal', 2.0794415416798357),
#  ('interweaving', 2.0794415416798357),
#  ('janeway', 2.0794415416798357),
#  ('lupin', 2.0794415416798357),
#  ('olan', 2.0794415416798357),
#  ('salva', 2.0794415416798357),
#  ('micheaux', 2.0794415416798357),
#  ('improvising', 2.0794415416798357),
#  ('iago', 2.0794415416798357),
#  ('kemble', 2.0794415416798357),
#  ('littlefield', 2.0794415416798357),
#  ('pernell', 2.0794415416798357),
#  ('tiempo', 2.0794415416798357),
#  ('valientes', 2.0794415416798357),
#  ('hohl', 2.0794415416798357),
#  ('brommel', 2.0794415416798357),
#  ('ezra', 2.0794415416798357),
#  ('fez', 2.0794415416798357),
#  ('kangwon', 2.0794415416798357),
#  ('lodoss', 2.0794415416798357),
#  ('eon', 2.0794415416798357),
#  ('lachaise', 2.0794415416798357),
#  ('salles', 2.0794415416798357),
#  ('marais', 2.0794415416798357),
#  ('shinae', 2.0794415416798357),
#  ('stphane', 2.0794415416798357),
#  ('goodrich', 2.0794415416798357),
#  ('gades', 2.0794415416798357),
#  ('zorak', 2.0794415416798357),
#  ('rambeau', 2.0794415416798357),
#  ('kaakha', 2.0794415416798357),
#  ('thuggee', 2.0794415416798357),
#  ('ciannelli', 2.0794415416798357),
#  ('locataire', 2.0794415416798357),
#  ('taj', 2.0794415416798357),
#  ('benito', 2.0794415416798357),
#  ('fastway', 2.0794415416798357),
#  ('jafri', 2.0794415416798357),
#  ('kopins', 2.0794415416798357),
#  ('hiralal', 2.0794415416798357),
#  ('duryea', 2.0794415416798357),
#  ('loomis', 2.0794415416798357),
#  ('nekron', 2.0794415416798357),
#  ('etzel', 2.0794415416798357),
#  ('sandhya', 2.0794415416798357),
#  ('cabell', 2.0794415416798357),
#  ('alekos', 2.0794415416798357),
#  ('valseuses', 2.0794415416798357),
#  ('boesman', 2.0794415416798357),
#  ('ryker', 2.0794415416798357),
#  ('carax', 2.0794415416798357),
#  ('mnm', 2.0794415416798357),
#  ('queenie', 2.0794415416798357),
#  ('genma', 2.0794415416798357),
#  ('catiii', 2.0794415416798357),
#  ('peaches', 2.0794415416798357),
#  ('cheech', 2.0541237336955462),
#  ('heartbreaking', 2.05127066471314),
#  ('powell', 2.05127066471314),
#  ('scoop', 2.0476928433652555),
#  ('dandy', 2.0476928433652555),
#  ('cypher', 2.0476928433652555),
#  ('fairytale', 2.0476928433652555),
#  ('tel', 2.0476928433652555),
#  ('ella', 2.0476928433652555),
#  ('askey', 2.0476928433652555),
#  ('mol', 2.0476928433652555),
#  ('frailty', 2.03688192726104),
#  ('pawn', 2.03688192726104),
#  ('strathairn', 2.03688192726104),
#  ('quotable', 2.03688192726104),
#  ('tintin', 2.03688192726104),
#  ('judi', 2.03688192726104),
#  ('curtiz', 2.03688192726104),
#  ('duchess', 2.03688192726104),
#  ('pickford', 2.031432322493475),
#  ('clarence', 2.028148247292285),
#  ('wonderfully', 2.0215475632609334),
#  ('captures', 2.017369113037458),
#  ('sultan', 2.0149030205422647),
#  ('cameroon', 2.0149030205422647),
#  ('silvio', 2.0149030205422647),
#  ('ephemeral', 2.0149030205422647),
#  ('accomplishes', 2.0149030205422647),
#  ('sasha', 2.0149030205422647),
#  ('kessler', 2.0149030205422647),
#  ('tetsuo', 2.0149030205422647),
#  ('archibald', 2.0149030205422647),
#  ('laird', 2.0149030205422647),
#  ('gilley', 2.0149030205422647),
#  ('stalkers', 2.0149030205422647),
#  ('saffron', 2.0149030205422647),
#  ('brokedown', 2.0149030205422647),
#  ('masterful', 1.9965538818740682),
#  ('finlay', 1.992430164690206),
#  ('stairway', 1.992430164690206),
#  ('refreshingly', 1.992430164690206),
#  ('noriko', 1.992430164690206),
#  ('egan', 1.992430164690206),
#  ('pickpocket', 1.992430164690206),
#  ('bozz', 1.992430164690206),
#  ('teal', 1.9810014688665833),
#  ('lighten', 1.9810014688665833),
#  ('venezuela', 1.9810014688665833),
#  ('enthralling', 1.9740810260220096),
#  ('voight', 1.9560625205193314),
#  ('brosnan', 1.9547990964725592),
#  ('blindness', 1.9459101490553132),
#  ('transitional', 1.9459101490553132),
#  ('gibney', 1.9459101490553132),
#  ('plunged', 1.9459101490553132),
#  ('southampton', 1.9459101490553132),
#  ('subtler', 1.9459101490553132),
#  ('qualm', 1.9459101490553132),
#  ('expertly', 1.9459101490553132),
#  ('unforgettably', 1.9459101490553132),
#  ('miikes', 1.9459101490553132),
#  ('phoebe', 1.9459101490553132),
#  ('supper', 1.9459101490553132),
#  ('raja', 1.9459101490553132),
#  ('vulnerability', 1.9459101490553132),
#  ('butterflies', 1.9459101490553132),
#  ('marla', 1.9459101490553132),
#  ('illumination', 1.9459101490553132),
#  ('pinto', 1.9459101490553132),
#  ('accessory', 1.9459101490553132),
#  ('circumstantial', 1.9459101490553132),
#  ('aborigine', 1.9459101490553132),
#  ('shimmering', 1.9459101490553132),
#  ('rosza', 1.9459101490553132),
#  ('deposed', 1.9459101490553132),
#  ('perinal', 1.9459101490553132),
#  ('magnificently', 1.9459101490553132),
#  ('lajos', 1.9459101490553132),
#  ('raoul', 1.9459101490553132),
#  ('vienna', 1.9459101490553132),
#  ('shumlin', 1.9459101490553132),
#  ('matchmaker', 1.9459101490553132),
#  ('fingerprints', 1.9459101490553132),
#  ('austens', 1.9459101490553132),
#  ('sayings', 1.9459101490553132),
#  ('lamm', 1.9459101490553132),
#  ('incisive', 1.9459101490553132),
#  ('dauphine', 1.9459101490553132),
#  ('rending', 1.9459101490553132),
#  ('wtc', 1.9459101490553132),
#  ('ligabue', 1.9459101490553132),
#  ('milder', 1.9459101490553132),
#  ('overjoyed', 1.9459101490553132),
#  ('rataud', 1.9459101490553132),
#  ('laudenbach', 1.9459101490553132),
#  ('laroche', 1.9459101490553132),
#  ('attaches', 1.9459101490553132),
#  ('unwillingly', 1.9459101490553132),
#  ('trebor', 1.9459101490553132),
#  ('sirico', 1.9459101490553132),
#  ('melfi', 1.9459101490553132),
#  ('carmela', 1.9459101490553132),
#  ('recognizably', 1.9459101490553132),
#  ('stunner', 1.9459101490553132),
#  ('akane', 1.9459101490553132),
#  ('sortie', 1.9459101490553132),
#  ('rawlins', 1.9459101490553132),
#  ('carre', 1.9459101490553132),
#  ('prosper', 1.9459101490553132),
#  ('citizenx', 1.9459101490553132),
#  ('edelman', 1.9459101490553132),
#  ('singin', 1.9459101490553132),
#  ('differing', 1.9459101490553132),
#  ('rathbone', 1.9459101490553132),
#  ('francois', 1.9459101490553132),
#  ('riedelsheimer', 1.9459101490553132),
#  ('demeanour', 1.9459101490553132),
#  ('melle', 1.9459101490553132),
#  ('costly', 1.9459101490553132),
#  ('novela', 1.9459101490553132),
#  ('cleanliness', 1.9459101490553132),
#  ('trusts', 1.9459101490553132),
#  ('ripner', 1.9459101490553132),
#  ('persistence', 1.9459101490553132),
#  ('tessari', 1.9459101490553132),
#  ('mcclurg', 1.9459101490553132),
#  ('evocation', 1.9459101490553132),
#  ('reassuring', 1.9459101490553132),
#  ('hightower', 1.9459101490553132),
#  ('korsmo', 1.9459101490553132),
#  ('rapids', 1.9459101490553132),
#  ('moroder', 1.9459101490553132),
#  ('loulou', 1.9459101490553132),
#  ('pransky', 1.9459101490553132),
#  ('bogarde', 1.9459101490553132),
#  ('reckoned', 1.9459101490553132),
#  ('scaffolding', 1.9459101490553132),
#  ('roo', 1.9459101490553132),
#  ('izumo', 1.9459101490553132),
#  ('jouvet', 1.9459101490553132),
#  ('piaf', 1.9459101490553132),
#  ('junkermann', 1.9459101490553132),
#  ('enlisting', 1.9459101490553132),
#  ('cantankerous', 1.9459101490553132),
#  ('kikuno', 1.9459101490553132),
#  ('kurasawa', 1.9459101490553132),
#  ('guarding', 1.9459101490553132),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('boll', -4.997212273764115),
#  ('uwe', -4.6443908991413725),
#  ('thunderbirds', -4.127134385045092),
#  ('beowulf', -4.110873864173311),
#  ('dahmer', -3.9889840465642745),
#  ('seagal', -3.960813169597578),
#  ('wayans', -3.951243718581427),
#  ('ajay', -3.871201010907891),
#  ('grendel', -3.871201010907891),
#  ('steaming', -3.6635616461296463),
#  ('deathstalker', -3.5553480614894135),
#  ('segal', -3.5263605246161616),
#  ('interminable', -3.4965075614664802),
#  ('sabretooth', -3.4339872044851463),
#  ('forwarding', -3.4011973816621555),
#  ('devgan', -3.367295829986474),
#  ('gamera', -3.332204510175204),
#  ('razzie', -3.332204510175204),
#  ('unwatchable', -3.332204510175204),
#  ('varma', -3.295836866004329),
#  ('picker', -3.295836866004329),
#  ('stinker', -3.248434627109745),
#  ('kirkland', -3.2188758248682006),
#  ('kgb', -3.2188758248682006),
#  ('nada', -3.2188758248682006),
#  ('hacked', -3.1780538303479458),
#  ('nostril', -3.1780538303479458),
#  ('giamatti', -3.1780538303479458),
#  ('appallingly', -3.1780538303479458),
#  ('pointlessly', -3.1354942159291497)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = total_counts.keys()

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1, vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'bromwell': 0,
#  'high': 1,
#  'is': 2,
#  'a': 3,
#  'cartoon': 4,
#  'comedy': 5,
#  '.': 6,
#  'it': 7,
#  'ran': 8,
#  'at': 9,
#  'the': 10,
#  'same': 11,
#  'time': 12,
#  'as': 13,
#  'some': 14,
#  'other': 15,
#  'programs': 16,
#  'about': 17,
#  'school': 18,
#  'life': 19,
#  '': 20,
#  'such': 21,
#  'teachers': 22,
#  'my': 23,
#  'years': 24,
#  'in': 25,
#  'teaching': 26,
#  'profession': 27,
#  'lead': 28,
#  'me': 29,
#  'to': 30,
#  'believe': 31,
#  'that': 32,
#  's': 33,
#  'satire': 34,
#  'much': 35,
#  'closer': 36,
#  'reality': 37,
#  'than': 38,
#  'scramble': 39,
#  'survive': 40,
#  'financially': 41,
#  'insightful': 42,
#  'students': 43,
#  'who': 44,
#  'can': 45,
#  'see': 46,
#  'right': 47,
#  'through': 48,
#  'their': 49,
#  'pathetic': 50,
#  'pomp': 51,
#  'pettiness': 52,
#  'of': 53,
#  'whole': 54,
#  'situation': 55,
#  'all': 56,
#  'remind': 57,
#  'schools': 58,
#  'i': 59,
#  'knew': 60,
#  'and': 61,
#  'when': 62,
#  'saw': 63,
#  'episode': 64,
#  'which': 65,
#  'student': 66,
#  'repeatedly': 67,
#  'tried': 68,
#  'burn': 69,
#  'down': 70,
#  'immediately': 71,
#  'recalled': 72,
#  'classic': 73,
#  'line': 74,
#  'inspector': 75,
#  'm': 76,
#  'here': 77,
#  'sack': 78,
#  'one': 79,
#  'your': 80,
#  'welcome': 81,
#  'expect': 82,
#  'many': 83,
#  'adults': 84,
#  'age': 85,
#  'think': 86,
#  'far': 87,
#  'fetched': 88,
#  'what': 89,
#  'pity': 90,
#  'isn': 91,
#  't': 92,
#  'story': 93,
#  'man': 94,
#  'has': 95,
#  'unnatural': 96,
#  'feelings': 97,
#  'for': 98,
#  'pig': 99,
#  'starts': 100,
#  'out': 101,
#  'with': 102,
#  'opening': 103,
#  'scene': 104,
#  'terrific': 105,
#  'example': 106,
#  'absurd': 107,
#  'formal': 108,
#  'orchestra': 109,
#  'audience': 110,
#  'turned': 111,
#  'into': 112,
#  'an': 113,
#  'insane': 114,
#  'violent': 115,
#  'mob': 116,
#  'by': 117,
#  'crazy': 118,
#  'chantings': 119,
#  'singers': 120,
#  'unfortunately': 121,
#  'stays': 122,
#  'no': 123,
#  'general': 124,
#  'narrative': 125,
#  'eventually': 126,
#  'making': 127,
#  'just': 128,
#  'too': 129,
#  'off': 130,
#  'putting': 131,
#  'even': 132,
#  'those': 133,
#  'from': 134,
#  'era': 135,
#  'should': 136,
#  'be': 137,
#  'cryptic': 138,
#  'dialogue': 139,
#  'would': 140,
#  'make': 141,
#  'shakespeare': 142,
#  'seem': 143,
#  'easy': 144,
#  'third': 145,
#  'grader': 146,
#  'on': 147,
#  'technical': 148,
#  'level': 149,
#  'better': 150,
#  'you': 151,
#  'might': 152,
#  'good': 153,
#  'cinematography': 154,
#  'future': 155,
#  'great': 156,
#  'vilmos': 157,
#  'zsigmond': 158,
#  'stars': 159,
#  'sally': 160,
#  'kirkland': 161,
#  'frederic': 162,
#  'forrest': 163,
#  'seen': 164,
#  'briefly': 165,
#  'homelessness': 166,
#  'or': 167,
#  'houselessness': 168,
#  'george': 169,
#  'carlin': 170,
#  'stated': 171,
#  'been': 172,
#  'issue': 173,
#  'but': 174,
#  'never': 175,
#  'plan': 176,
#  'help': 177,
#  'street': 178,
#  'were': 179,
#  'once': 180,
#  'considered': 181,
#  'human': 182,
#  'did': 183,
#  'everything': 184,
#  'going': 185,
#  'work': 186,
#  'vote': 187,
#  'matter': 188,
#  'most': 189,
#  'people': 190,
#  'homeless': 191,
#  'lost': 192,
#  'cause': 193,
#  'while': 194,
#  'worrying': 195,
#  'things': 196,
#  'racism': 197,
#  'war': 198,
#  'iraq': 199,
#  'pressuring': 200,
#  'kids': 201,
#  'succeed': 202,
#  'technology': 203,
#  'elections': 204,
#  'inflation': 205,
#  'if': 206,
#  'they': 207,
#  'll': 208,
#  'next': 209,
#  'end': 210,
#  'up': 211,
#  'streets': 212,
#  'br': 213,
#  'given': 214,
#  'bet': 215,
#  'live': 216,
#  'month': 217,
#  'without': 218,
#  'luxuries': 219,
#  'had': 220,
#  'home': 221,
#  'entertainment': 222,
#  'sets': 223,
#  'bathroom': 224,
#  'pictures': 225,
#  'wall': 226,
#  'computer': 227,
#  'treasure': 228,
#  'like': 229,
#  'goddard': 230,
#  'bolt': 231,
#  'lesson': 232,
#  'mel': 233,
#  'brooks': 234,
#  'directs': 235,
#  'plays': 236,
#  'rich': 237,
#  'world': 238,
#  'until': 239,
#  'deciding': 240,
#  'sissy': 241,
#  'rival': 242,
#  'jeffery': 243,
#  'tambor': 244,
#  'he': 245,
#  'thirty': 246,
#  'days': 247,
#  'succeeds': 248,
#  'do': 249,
#  'wants': 250,
#  'project': 251,
#  'more': 252,
#  'buildings': 253,
#  'where': 254,
#  'thrown': 255,
#  'bracelet': 256,
#  'his': 257,
#  'leg': 258,
#  'monitor': 259,
#  'every': 260,
#  'move': 261,
#  'step': 262,
#  'sidewalk': 263,
#  'nickname': 264,
#  'pepto': 265,
#  'vagrant': 266,
#  'after': 267,
#  'written': 268,
#  'forehead': 269,
#  'meets': 270,
#  'characters': 271,
#  'including': 272,
#  'woman': 273,
#  'name': 274,
#  'molly': 275,
#  'lesley': 276,
#  'ann': 277,
#  'warren': 278,
#  'ex': 279,
#  'dancer': 280,
#  'got': 281,
#  'divorce': 282,
#  'before': 283,
#  'losing': 284,
#  'her': 285,
#  'pals': 286,
#  'sailor': 287,
#  'howard': 288,
#  'morris': 289,
#  'fumes': 290,
#  'teddy': 291,
#  'wilson': 292,
#  'are': 293,
#  'already': 294,
#  'used': 295,
#  're': 296,
#  'survivors': 297,
#  'not': 298,
#  'reaching': 299,
#  'mutual': 300,
#  'agreements': 301,
#  'being': 302,
#  'fight': 303,
#  'flight': 304,
#  'kill': 305,
#  'killed': 306,
#  'love': 307,
#  'connection': 308,
#  'between': 309,
#  'wasn': 310,
#  'necessary': 311,
#  'plot': 312,
#  'found': 313,
#  'stinks': 314,
#  'observant': 315,
#  'films': 316,
#  'prior': 317,
#  'shows': 318,
#  'tender': 319,
#  'side': 320,
#  'compared': 321,
#  'slapstick': 322,
#  'blazing': 323,
#  'saddles': 324,
#  'young': 325,
#  'frankenstein': 326,
#  'spaceballs': 327,
#  'show': 328,
#  'having': 329,
#  'something': 330,
#  'valuable': 331,
#  'day': 332,
#  'hand': 333,
#  'stupid': 334,
#  'don': 335,
#  'know': 336,
#  'money': 337,
#  'maybe': 338,
#  'give': 339,
#  'instead': 340,
#  'using': 341,
#  'monopoly': 342,
#  'this': 343,
#  'film': 344,
#  'will': 345,
#  'inspire': 346,
#  'others': 347,
#  'airport': 348,
#  'brand': 349,
#  'new': 350,
#  'luxury': 351,
#  'plane': 352,
#  'loaded': 353,
#  'paintings': 354,
#  'belonging': 355,
#  'businessman': 356,
#  'philip': 357,
#  'stevens': 358,
#  'james': 359,
#  'stewart': 360,
#  'flying': 361,
#  'them': 362,
#  'bunch': 363,
#  'vip': 364,
#  'estate': 365,
#  'preparation': 366,
#  'opened': 367,
#  'public': 368,
#  'museum': 369,
#  'also': 370,
#  'board': 371,
#  'daughter': 372,
#  'julie': 373,
#  'kathleen': 374,
#  'quinlan': 375,
#  'son': 376,
#  'jetliner': 377,
#  'takes': 378,
#  'planned': 379,
#  'mid': 380,
#  'air': 381,
#  'hi': 382,
#  'jacked': 383,
#  'co': 384,
#  'pilot': 385,
#  'chambers': 386,
#  'robert': 387,
#  'foxworth': 388,
#  'two': 389,
#  'accomplice': 390,
#  'banker': 391,
#  'monte': 392,
#  'markham': 393,
#  'michael': 394,
#  'pataki': 395,
#  'knock': 396,
#  'passengers': 397,
#  'crew': 398,
#  'sleeping': 399,
#  'gas': 400,
#  'steal': 401,
#  'cargo': 402,
#  'land': 403,
#  'disused': 404,
#  'strip': 405,
#  'isolated': 406,
#  'island': 407,
#  'descent': 408,
#  'almost': 409,
#  'hits': 410,
#  'oil': 411,
#  'rig': 412,
#  'ocean': 413,
#  'loses': 414,
#  'control': 415,
#  'sending': 416,
#  'crashing': 417,
#  'sea': 418,
#  'sinks': 419,
#  'bottom': 420,
#  'bang': 421,
#  'middle': 422,
#  'bermuda': 423,
#  'triangle': 424,
#  'short': 425,
#  'supply': 426,
#  'water': 427,
#  'leaking': 428,
#  'flown': 429,
#  'over': 430,
#  'miles': 431,
#  'course': 432,
#  'problems': 433,
#  'mount': 434,
#  'survivor': 435,
#  'await': 436,
#  'fast': 437,
#  'running': 438,
#  'known': 439,
#  'under': 440,
#  'slightly': 441,
#  'different': 442,
#  'tile': 443,
#  'second': 444,
#  'sequel': 445,
#  'smash': 446,
#  'hit': 447,
#  'disaster': 448,
#  'thriller': 449,
#  'was': 450,
#  'directed': 451,
#  'jerry': 452,
#  'jameson': 453,
#  'again': 454,
#  'predecessors': 455,
#  'say': 456,
#  'any': 457,
#  'sort': 458,
#  'forgotten': 459,
#  'entertaining': 460,
#  'although': 461,
#  'necessarily': 462,
#  'reasons': 463,
#  'three': 464,
#  'have': 465,
#  'so': 466,
#  'actually': 467,
#  'liked': 468,
#  'best': 469,
#  'favourite': 470,
#  'nice': 471,
#  'jacking': 472,
#  'then': 473,
#  'didn': 474,
#  'sinking': 475,
#  'makers': 476,
#  'trying': 477,
#  'cross': 478,
#  'original': 479,
#  'another': 480,
#  'popular': 481,
#  'flick': 482,
#  'period': 483,
#  'poseidon': 484,
#  'adventure': 485,
#  'submerged': 486,
#  'stark': 487,
#  'dilemma': 488,
#  'facing': 489,
#  'trapped': 490,
#  'inside': 491,
#  'either': 492,
#  'suffocate': 493,
#  'runs': 494,
#  'drown': 495,
#  'floods': 496,
#  'doors': 497,
#  'decent': 498,
#  'idea': 499,
#  'could': 500,
#  'made': 501,
#  'little': 502,
#  'bad': 503,
#  'unsympathetic': 504,
#  'character': 505,
#  'dull': 506,
#  'lethargic': 507,
#  'set': 508,
#  'pieces': 509,
#  'real': 510,
#  'lack': 511,
#  'danger': 512,
#  'suspense': 513,
#  'tension': 514,
#  'means': 515,
#  'missed': 516,
#  'opportunity': 517,
#  'rather': 518,
#  'sluggish': 519,
#  'keeps': 520,
#  'entertained': 521,
#  'odd': 522,
#  'minutes': 523,
#  'happens': 524,
#  'there': 525,
#  'urgency': 526,
#  'thought': 527,
#  'navy': 528,
#  'become': 529,
#  'involved': 530,
#  'pick': 531,
#  'few': 532,
#  'shots': 533,
#  'huge': 534,
#  'ships': 535,
#  'helicopters': 536,
#  'lacking': 537,
#  'kennedy': 538,
#  'jinxed': 539,
#  'airline': 540,
#  'worker': 541,
#  'joe': 542,
#  'patroni': 543,
#  'back': 544,
#  'only': 545,
#  'gets': 546,
#  'couple': 547,
#  'scenes': 548,
#  'barely': 549,
#  'says': 550,
#  'anything': 551,
#  'preferring': 552,
#  'look': 553,
#  'worried': 554,
#  'background': 555,
#  'video': 556,
#  'theatrical': 557,
#  'version': 558,
#  'run': 559,
#  'us': 560,
#  'tv': 561,
#  'versions': 562,
#  'add': 563,
#  'extra': 564,
#  'hour': 565,
#  'footage': 566,
#  'credits': 567,
#  'sequence': 568,
#  'flashbacks': 569,
#  'flesh': 570,
#  'longer': 571,
#  'rescue': 572,
#  'discovery': 573,
#  'dead': 574,
#  'bodies': 575,
#  'navigator': 576,
#  'am': 577,
#  'sure': 578,
#  'sit': 579,
#  'near': 580,
#  'cut': 581,
#  'expected': 582,
#  'dated': 583,
#  'badly': 584,
#  'horrible': 585,
#  'fashions': 586,
#  'interior': 587,
#  'design': 588,
#  'choices': 589,
#  'toy': 590,
#  'model': 591,
#  'effects': 592,
#  'aren': 593,
#  'along': 594,
#  'sequels': 595,
#  'pride': 596,
#  'place': 597,
#  'razzie': 598,
#  'award': 599,
#  'hall': 600,
#  'shame': 601,
#  'lots': 602,
#  'worse': 603,
#  'reckon': 604,
#  'harsh': 605,
#  'action': 606,
#  'pace': 607,
#  'slow': 608,
#  'excitement': 609,
#  'generated': 610,
#  'pretty': 611,
#  'properly': 612,
#  'production': 613,
#  'values': 614,
#  'alright': 615,
#  'nothing': 616,
#  'spectacular': 617,
#  'acting': 618,
#  'oscar': 619,
#  'winner': 620,
#  'jack': 621,
#  'lemmon': 622,
#  'said': 623,
#  'since': 624,
#  'mistake': 625,
#  'star': 626,
#  'looks': 627,
#  'old': 628,
#  'frail': 629,
#  'lee': 630,
#  'grant': 631,
#  'drunk': 632,
#  'sir': 633,
#  'christopher': 634,
#  'plenty': 635,
#  'familiar': 636,
#  'faces': 637,
#  'orientated': 638,
#  'ideas': 639,
#  'behind': 640,
#  'bit': 641,
#  'silly': 642,
#  'bland': 643,
#  'direction': 644,
#  'doesn': 645,
#  'though': 646,
#  'sunken': 647,
#  'shouldn': 648,
#  'boring': 649,
#  'followed': 650,
#  'concorde': 651,
#  'brilliant': 652,
#  'dramatic': 653,
#  'hobo': 654,
#  'lady': 655,
#  'ever': 656,
#  'clothes': 657,
#  'warehouse': 658,
#  'none': 659,
#  'corn': 660,
#  'face': 661,
#  'take': 662,
#  'lawyers': 663,
#  'superb': 664,
#  'accused': 665,
#  'turncoat': 666,
#  'selling': 667,
#  'boss': 668,
#  'dishonest': 669,
#  'lawyer': 670,
#  'shrugs': 671,
#  'indifferently': 672,
#  'funny': 673,
#  'words': 674,
#  'jeffrey': 675,
#  'favorite': 676,
#  'later': 677,
#  'larry': 678,
#  'sanders': 679,
#  'fantastic': 680,
#  'mad': 681,
#  'millionaire': 682,
#  'crush': 683,
#  'ghetto': 684,
#  'malevolent': 685,
#  'usual': 686,
#  'hospital': 687,
#  'invade': 688,
#  'demolition': 689,
#  'site': 690,
#  'classics': 691,
#  'legs': 692,
#  'big': 693,
#  'diggers': 694,
#  'fighting': 695,
#  'bleeds': 696,
#  'movie': 697,
#  'each': 698,
#  'quite': 699,
#  'often': 700,
#  'lacked': 701,
#  'couldn': 702,
#  'put': 703,
#  'finger': 704,
#  'first': 705,
#  'charisma': 706,
#  'part': 707,
#  'leading': 708,
#  'actress': 709,
#  'inevitably': 710,
#  'translated': 711,
#  'chemistry': 712,
#  'she': 713,
#  'shared': 714,
#  'screen': 715,
#  'romantic': 716,
#  'came': 717,
#  'across': 718,
#  'merely': 719,
#  'actors': 720,
#  'play': 721,
#  'very': 722,
#  'well': 723,
#  'director': 724,
#  'miscalculated': 725,
#  'needed': 726,
#  'screenplay': 727,
#  'exactly': 728,
#  'chef': 729,
#  'seemed': 730,
#  'enamored': 731,
#  'culinary': 732,
#  'skills': 733,
#  'restaurant': 734,
#  'ultimately': 735,
#  'himself': 736,
#  'youthful': 737,
#  'exploits': 738,
#  'anybody': 739,
#  'else': 740,
#  'convinced': 741,
#  'princess': 742,
#  'disappointed': 743,
#  'forget': 744,
#  'nominated': 745,
#  'judge': 746,
#  'yourself': 747,
#  'easily': 748,
#  'underrated': 749,
#  'inn': 750,
#  'cannon': 751,
#  'its': 752,
#  'flawed': 753,
#  'does': 754,
#  'realistic': 755,
#  'view': 756,
#  'unlike': 757,
#  'how': 758,
#  'citizen': 759,
#  'kane': 760,
#  'gave': 761,
#  'lounge': 762,
#  'titanic': 763,
#  'italians': 764,
#  'idiots': 765,
#  'jokes': 766,
#  'fall': 767,
#  'flat': 768,
#  'still': 769,
#  'lovable': 770,
#  'way': 771,
#  'comedies': 772,
#  'pull': 773,
#  'traditionally': 774,
#  'reviled': 775,
#  'members': 776,
#  'society': 777,
#  'truly': 778,
#  'impressive': 779,
#  'fisher': 780,
#  'king': 781,
#  'crap': 782,
#  'complaint': 783,
#  'cast': 784,
#  'someone': 785,
#  'writer': 786,
#  'sorry': 787,
#  'everyone': 788,
#  'supposed': 789,
#  'art': 790,
#  'wow': 791,
#  'handed': 792,
#  'guns': 793,
#  'screening': 794,
#  'blow': 795,
#  'brains': 796,
#  'watch': 797,
#  'photographic': 798,
#  'excellent': 799,
#  'painful': 800,
#  'absence': 801,
#  'sound': 802,
#  'track': 803,
#  'brutal': 804,
#  'loooonnnnng': 805,
#  'long': 806,
#  'sitting': 807,
#  'talking': 808,
#  'especially': 809,
#  'complaining': 810,
#  'really': 811,
#  'hard': 812,
#  'getting': 813,
#  'performances': 814,
#  'dark': 815,
#  'sombre': 816,
#  'uninspired': 817,
#  'stuff': 818,
#  'thing': 819,
#  'maureen': 820,
#  'stapleton': 821,
#  'red': 822,
#  'dress': 823,
#  'dancing': 824,
#  'otherwise': 825,
#  'ripoff': 826,
#  'bergman': 827,
#  'fan': 828,
#  'f': 829,
#  'anyone': 830,
#  'enjoyed': 831,
#  'hours': 832,
#  'lying': 833,
#  'typical': 834,
#  'less': 835,
#  'movies': 836,
#  'followable': 837,
#  'leslie': 838,
#  'rated': 839,
#  'moments': 840,
#  'fleshed': 841,
#  'probably': 842,
#  'room': 843,
#  'worth': 844,
#  'price': 845,
#  'rent': 846,
#  'overall': 847,
#  'job': 848,
#  'characteristic': 849,
#  'speaking': 850,
#  'directly': 851,
#  'actor': 852,
#  'fume': 853,
#  'both': 854,
#  'played': 855,
#  'parts': 856,
#  'parents': 857,
#  'took': 858,
#  'theater': 859,
#  'interiors': 860,
#  'watched': 861,
#  'we': 862,
#  'walked': 863,
#  'recently': 864,
#  'lived': 865,
#  'rest': 866,
#  'pretentious': 867,
#  'ponderous': 868,
#  'painfully': 869,
#  'piece': 870,
#  'wine': 871,
#  'cheese': 872,
#  'tripe': 873,
#  'woody': 874,
#  'allen': 875,
#  'directors': 876,
#  'worst': 877,
#  'career': 878,
#  'unmistakable': 879,
#  'style': 880,
#  'ingmar': 881,
#  'berman': 882,
#  'gives': 883,
#  'angular': 884,
#  'muted': 885,
#  'insight': 886,
#  'lives': 887,
#  'family': 888,
#  'wrought': 889,
#  'psychological': 890,
#  'damage': 891,
#  'caused': 892,
#  'estrangement': 893,
#  'non': 894,
#  'halitosis': 895,
#  'whatever': 896,
#  'intentionally': 897,
#  'comic': 898,
#  'relief': 899,
#  'music': 900,
#  'drenched': 901,
#  'shadowy': 902,
#  'pathos': 903,
#  'defined': 904,
#  'expressionist': 905,
#  'nature': 906,
#  'improvisational': 907,
#  'method': 908,
#  'illicit': 909,
#  'pronounced': 910,
#  'depth': 911,
#  'meaning': 912,
#  'truth': 913,
#  'beyond': 914,
#  'simply': 915,
#  'sympathy': 916,
#  'felt': 917,
#  'contempt': 918,
#  'parade': 919,
#  'shuffling': 920,
#  'whining': 921,
#  'nicotine': 922,
#  'stained': 923,
#  'martyrs': 924,
#  'perpetual': 925,
#  'quest': 926,
#  'identity': 927,
#  'amid': 928,
#  'backdrop': 929,
#  'cosmopolitan': 930,
#  'affluence': 931,
#  'baked': 932,
#  'brie': 933,
#  'intelligentsia': 934,
#  'looms': 935,
#  'fart': 936,
#  'speaks': 937,
#  'affected': 938,
#  'platitudes': 939,
#  'elevated': 940,
#  'language': 941,
#  'cigarettes': 942,
#  'struggling': 943,
#  'desperate': 944,
#  'find': 945,
#  'understanding': 946,
#  'goes': 947,
#  'point': 948,
#  'want': 949,
#  'slap': 950,
#  'resolution': 951,
#  'interminable': 952,
#  'introspective': 953,
#  'babble': 954,
#  'drama': 955,
#  'taken': 956,
#  'extreme': 957,
#  'ability': 958,
#  'connect': 959,
#  'chose': 960,
#  'immersed': 961,
#  'themselves': 962,
#  'feel': 963,
#  'left': 964,
#  'reason': 965,
#  'self': 966,
#  'indulgent': 967,
#  'spiritually': 968,
#  'draining': 969,
#  'insistence': 970,
#  'promoting': 971,
#  'message': 972,
#  'prozac': 973,
#  'prose': 974,
#  'distorted': 975,
#  'techniques': 976,
#  'jettisons': 977,
#  'past': 978,
#  'relevance': 979,
#  'highly': 980,
#  'recommend': 981,
#  'feeling': 982,
#  'happy': 983,
#  'need': 984,
#  'death': 985,
#  'let': 986,
#  'pretend': 987,
#  'happened': 988,
#  'comedic': 989,
#  'robin': 990,
#  'williams': 991,
#  'nor': 992,
#  'quirky': 993,
#  'recent': 994,
#  'fame': 995,
#  'hybrid': 996,
#  'dramatization': 997,
#  'mixed': 998,
#  'per': 999,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    # TODO: count how many times each word is used in the given review and store the results in layer_0 
    for word, count in Counter(review.split(" ")).items():
        layer_0[0][word2index[word]] = count

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[4., 5., 4., ..., 0., 0., 0.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    if label == 'POSITIVE':
        return 1
    return 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        # TODO: populate review_vocab with all of the words in the given reviews
        #       Remember to split reviews into individual words 
        #       using "split(' ')" instead of "split()".
        
        # Convert the vocabulary set to a list so we can access words via indices
        review_vocab = set([word in reviews.split(" ")])
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        # TODO: populate label_vocab with all of the words in the given labels.
        #       There is no need to split the labels because each one is a single word.
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        label_vocab = set(lablels)
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        # TODO: populate self.word2index with indices for all the words in self.review_vocab
        #       like you saw earlier in the notebook
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        # TODO: do the same thing you did for self.word2index and self.review_vocab, 
        #       but for self.label2index and self.label_vocab instead
        for i, word in enumerate(self.label_vocab):
            self.label2index[word] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes, self.hidden_nodes))
        
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.random((self.hidden_nodes, self.output_nodes))
        
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):
        # TODO: You can copy most of the code you wrote for update_input_layer 
        #       earlier in this notebook. 
        #
        #       However, MAKE SURE YOU CHANGE ALL VARIABLES TO REFERENCE
        #       THE VERSIONS STORED IN THIS OBJECT, NOT THE GLOBAL OBJECTS.
        #       For example, replace "layer_0 *= 0" with "self.layer_0 *= 0"
        # clear out previous state by resetting the layer to be all 0s
        self.layer_0 *= 0
        # TODO: count how many times each word is used in the given review and store the results in layer_0 
        for word, count in Counter(review.split(" ")).items():
            self.layer_0[0][word2index[word]] = count
                
    def get_target_for_label(self,label):
        # TODO: Copy the code you wrote for get_target_for_label 
        #       earlier in this notebook. 
        if label == 'POSITIVE':
            return 1
        return 0
        
    def sigmoid(self,x):
        # TODO: Return the result of calculating the sigmoid activation function
        #       shown in the lectures
        return 1/(1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        # TODO: Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid fucntion 
        return output * (1 - output)

    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.
            self.update_input_layer(review)
            input_to_hidden_layer = np.dot(self.layer_0, self.layer_0_1)
            input_to_output_layer = np.dot(input_to_hidden_layer, self.weights_1_2)
            output = sigmoid(input_to_output_layer)
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.
            error = self.get_target_for_label(label) - output
            hidden_error = error * self.weights_1_2
            output_error_term = error * self.sigmoid_output_2_derivative
            hidden_error_term = hidden_error
            delta_weights_i_h += hidden_error_term * self.layer0[:, None]
            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.
        pass

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# With a learning rate of `0.001`, the network should finall have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
