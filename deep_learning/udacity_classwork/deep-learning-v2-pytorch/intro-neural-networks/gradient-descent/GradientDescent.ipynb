# %% [markdown]
# # Implementing the Gradient Descent Algorithm
#
# In this lab, we'll implement the basic functions of the Gradient Descent algorithm to find the boundary in a small dataset. First, we'll start with some functions that will help us plot and visualize the data.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#Some helper functions for plotting and drawing lines

def plot_points(X, y):
    admitted = X[np.argwhere(y==1)]
    rejected = X[np.argwhere(y==0)]
    plt.scatter([s[0][0] for s in rejected], [s[0][1] for s in rejected], s = 25, color = 'blue', edgecolor = 'k')
    plt.scatter([s[0][0] for s in admitted], [s[0][1] for s in admitted], s = 25, color = 'red', edgecolor = 'k')

def display(m, b, color='g--'):
    plt.xlim(-0.05,1.05)
    plt.ylim(-0.05,1.05)
    x = np.arange(-10, 10, 0.1)
    plt.plot(x, m*x+b, color)

# %% [markdown]
# ## Reading and plotting the data

# %%
data = pd.read_csv('data.csv', header=None)
X = np.array(data[[0,1]])
y = np.array(data[2])
plot_points(X,y)
plt.show()

# %% [markdown]
# ## TODO: Implementing the basic functions
# Here is your turn to shine. Implement the following formulas, as explained in the text.
# - Sigmoid activation function
#
# $$\sigma(x) = \frac{1}{1+e^{-x}}$$
#
# - Output (prediction) formula
#
# $$\hat{y} = \sigma(w_1 x_1 + w_2 x_2 + b)$$
#
# - Error function
#
# $$Error(y, \hat{y}) = - y \log(\hat{y}) - (1-y) \log(1-\hat{y})$$
#
# - The function that updates the weights
#
# $$ w_i \longrightarrow w_i + \alpha (y - \hat{y}) x_i$$
#
# $$ b \longrightarrow b + \alpha (y - \hat{y})$$

# %%
# Implement the following functions

# Activation (sigmoid) function
def sigmoid(x):
    retval = 1 / (1 + np.exp(-1 * x))
    return retval

# Output (prediction) formula
def output_formula(features, weights, bias):
    retval = sigmoid(np.dot(features, weights) + bias)
    return retval

# Error (log-loss) formula
def error_formula(y, output):
    retval = -1 * (y * np.log(output) - (1-y) * np.log(1 - output))
    return retval

# Gradient descent step
def update_weights(x, y, weights, bias, learnrate):
    W = np.zeros(weights.shape)
    W = weights + learnrate * (y - output_formula(x, weights, bias)) * x
    B = bias + learnrate * (y - output_formula(x, weights, bias))
    return W, B

# %% [markdown]
# ## Training function
# This function will help us iterate the gradient descent algorithm through all the data, for a number of epochs. It will also plot the data, and some of the boundary lines obtained as we run the algorithm.

# %%
np.random.seed(44)

epochs = 1000
learnrate = 0.01

def train(features, targets, epochs, learnrate, graph_lines=False):
    
    errors = []
    n_records, n_features = features.shape
    last_loss = None
    weights = np.random.normal(scale=1 / n_features**.5, size=n_features)
    bias = 0
    for e in range(epochs):
        del_w = np.zeros(weights.shape)
        for x, y in zip(features, targets):
            output = output_formula(x, weights, bias)
            error = error_formula(y, output)
            weights, bias = update_weights(x, y, weights, bias, learnrate)
        
        # Printing out the log-loss error on the training set
        out = output_formula(features, weights, bias)
        loss = np.mean(error_formula(targets, out))
        errors.append(loss)
        if e % (epochs / 100) == 0:
            print("\n========== Epoch", e,"==========")
            if last_loss and last_loss < loss:
                print("Train loss: ", loss, "  WARNING - Loss Increasing")
            else:
                print("Train loss: ", loss)
            last_loss = loss
            predictions = out > 0.5
            accuracy = np.mean(predictions == targets)
            print("Accuracy: ", accuracy)
        if graph_lines and e % (epochs / 1000) == 0:
            display(-weights[0]/weights[1], -bias/weights[1])
            

    # Plotting the solution boundary
    plt.title("Solution boundary")
    display(-weights[0]/weights[1], -bias/weights[1], 'black')

    # Plotting the data
    plot_points(features, targets)
    plt.show()

    # Plotting the error
    plt.title("Error Plot")
    plt.xlabel('Number of epochs')
    plt.ylabel('Error')
    plt.plot(errors)
    plt.show()

# %% [markdown]
# ## Time to train the algorithm!
# When we run the function, we'll obtain the following:
# - 10 updates with the current training loss and accuracy
# - A plot of the data and some of the boundary lines obtained. The final one is in black. Notice how the lines get closer and closer to the best fit, as we go through more epochs.
# - A plot of the error function. Notice how it decreases as we go through more epochs.

# %%
train(X, y, epochs, learnrate, True)
# Out:
# ========== Epoch 0 ==========
# Train loss:  -0.001635885803963908
# Accuracy:  0.4
#
# ========== Epoch 10 ==========
# Train loss:  0.1731078024236241   WARNING - Loss Increasing
# Accuracy:  0.59
#
# ========== Epoch 20 ==========
# Train loss:  0.14805218621137747
# Accuracy:  0.74
#
# ========== Epoch 30 ==========
# Train loss:  0.12628815990964293
# Accuracy:  0.84
#
# ========== Epoch 40 ==========
# Train loss:  0.10957125901546412
# Accuracy:  0.86
#
# ========== Epoch 50 ==========
# Train loss:  0.096516812274257
# Accuracy:  0.93
#
# ========== Epoch 60 ==========
# Train loss:  0.08612377653826854
# Accuracy:  0.93
#
# ========== Epoch 70 ==========
# Train loss:  0.07770072757127924
# Accuracy:  0.93
#
# ========== Epoch 80 ==========
# Train loss:  0.07076380783073391
# Accuracy:  0.94
#
# ========== Epoch 90 ==========
# Train loss:  0.06496847649412402
# Accuracy:  0.94
#
# ========== Epoch 100 ==========
# Train loss:  0.06006493448795272
# Accuracy:  0.94
#
# ========== Epoch 110 ==========
# Train loss:  0.05586885734853121
# Accuracy:  0.94
#
# ========== Epoch 120 ==========
# Train loss:  0.05224194436823324
# Accuracy:  0.94
#
# ========== Epoch 130 ==========
# Train loss:  0.0490787966203297
# Accuracy:  0.94
#
# ========== Epoch 140 ==========
# Train loss:  0.04629792167423645
# Accuracy:  0.94
#
# ========== Epoch 150 ==========
# Train loss:  0.043835467063047064
# Accuracy:  0.94
#
# ========== Epoch 160 ==========
# Train loss:  0.041640785646340286
# Accuracy:  0.94
#
# ========== Epoch 170 ==========
# Train loss:  0.03967324983143173
# Accuracy:  0.94
#
# ========== Epoch 180 ==========
# Train loss:  0.03789993014591176
# Accuracy:  0.94
#
# ========== Epoch 190 ==========
# Train loss:  0.03629388083190862
# Accuracy:  0.94
#
# ========== Epoch 200 ==========
# Train loss:  0.034832857723679785
# Accuracy:  0.94
#
# ========== Epoch 210 ==========
# Train loss:  0.03349834806445286
# Accuracy:  0.94
#
# ========== Epoch 220 ==========
# Train loss:  0.03227482824743345
# Accuracy:  0.94
#
# ========== Epoch 230 ==========
# Train loss:  0.031149190063024725
# Accuracy:  0.94
#
# ========== Epoch 240 ==========
# Train loss:  0.03011029290981039
# Accuracy:  0.94
#
# ========== Epoch 250 ==========
# Train loss:  0.029148611152122104
# Accuracy:  0.93
#
# ========== Epoch 260 ==========
# Train loss:  0.028255954053168053
# Accuracy:  0.93
#
# ========== Epoch 270 ==========
# Train loss:  0.027425241579044846
# Accuracy:  0.93
#
# ========== Epoch 280 ==========
# Train loss:  0.026650323588314352
# Accuracy:  0.93
#
# ========== Epoch 290 ==========
# Train loss:  0.02592583298805772
# Accuracy:  0.93
#
# ========== Epoch 300 ==========
# Train loss:  0.0252470656878898
# Accuracy:  0.93
#
# ========== Epoch 310 ==========
# Train loss:  0.024609881850546068
# Accuracy:  0.93
#
# ========== Epoch 320 ==========
# Train loss:  0.02401062418373115
# Accuracy:  0.93
#
# ========== Epoch 330 ==========
# Train loss:  0.023446049957070406
# Accuracy:  0.93
#
# ========== Epoch 340 ==========
# Train loss:  0.022913274141629646
# Accuracy:  0.93
#
# ========== Epoch 350 ==========
# Train loss:  0.022409721615642888
# Accuracy:  0.93
#
# ========== Epoch 360 ==========
# Train loss:  0.021933086801340138
# Accuracy:  0.93
#
# ========== Epoch 370 ==========
# Train loss:  0.021481299424787798
# Accuracy:  0.93
#
# ========== Epoch 380 ==========
# Train loss:  0.021052495346247858
# Accuracy:  0.93
#
# ========== Epoch 390 ==========
# Train loss:  0.020644991609473015
# Accuracy:  0.93
#
# ========== Epoch 400 ==========
# Train loss:  0.020257265017391092
# Accuracy:  0.93
#
# ========== Epoch 410 ==========
# Train loss:  0.019887933668106577
# Accuracy:  0.92
#
# ========== Epoch 420 ==========
# Train loss:  0.019535740986253856
# Accuracy:  0.92
#
# ========== Epoch 430 ==========
# Train loss:  0.01919954186617678
# Accuracy:  0.92
#
# ========== Epoch 440 ==========
# Train loss:  0.018878290609040532
# Accuracy:  0.92
#
# ========== Epoch 450 ==========
# Train loss:  0.01857103038940788
# Accuracy:  0.92
#
# ========== Epoch 460 ==========
# Train loss:  0.01827688403030341
# Accuracy:  0.92
#
# ========== Epoch 470 ==========
# Train loss:  0.017995045901444847
# Accuracy:  0.91
#
# ========== Epoch 480 ==========
# Train loss:  0.017724774784649348
# Accuracy:  0.91
#
# ========== Epoch 490 ==========
# Train loss:  0.01746538757463695
# Accuracy:  0.91
#
# ========== Epoch 500 ==========
# Train loss:  0.01721625370352632
# Accuracy:  0.91
#
# ========== Epoch 510 ==========
# Train loss:  0.016976790194055683
# Accuracy:  0.91
#
# ========== Epoch 520 ==========
# Train loss:  0.016746457260485154
# Accuracy:  0.91
#
# ========== Epoch 530 ==========
# Train loss:  0.01652475438784331
# Accuracy:  0.91
#
# ========== Epoch 540 ==========
# Train loss:  0.016311216830028084
# Accuracy:  0.91
#
# ========== Epoch 550 ==========
# Train loss:  0.016105412475551847
# Accuracy:  0.91
#
# ========== Epoch 560 ==========
# Train loss:  0.015906939036736942
# Accuracy:  0.91
#
# ========== Epoch 570 ==========
# Train loss:  0.015715421524148506
# Accuracy:  0.92
#
# ========== Epoch 580 ==========
# Train loss:  0.015530509973089503
# Accuracy:  0.92
#
# ========== Epoch 590 ==========
# Train loss:  0.015351877393328342
# Accuracy:  0.92
#
# ========== Epoch 600 ==========
# Train loss:  0.015179217916950639
# Accuracy:  0.92
#
# ========== Epoch 610 ==========
# Train loss:  0.015012245122335644
# Accuracy:  0.92
#
# ========== Epoch 620 ==========
# Train loss:  0.01485069051510583
# Accuracy:  0.92
#
# ========== Epoch 630 ==========
# Train loss:  0.01469430214910124
# Accuracy:  0.92
#
# ========== Epoch 640 ==========
# Train loss:  0.014542843372676719
# Accuracy:  0.92
#
# ========== Epoch 650 ==========
# Train loss:  0.01439609168707614
# Accuracy:  0.92
#
# ========== Epoch 660 ==========
# Train loss:  0.014253837705579824
# Accuracy:  0.92
#
# ========== Epoch 670 ==========
# Train loss:  0.01411588420304647
# Accuracy:  0.92
#
# ========== Epoch 680 ==========
# Train loss:  0.013982045246875694
# Accuracy:  0.92
#
# ========== Epoch 690 ==========
# Train loss:  0.013852145401434424
# Accuracy:  0.92
#
# ========== Epoch 700 ==========
# Train loss:  0.013726018998719822
# Accuracy:  0.92
#
# ========== Epoch 710 ==========
# Train loss:  0.013603509468969894
# Accuracy:  0.92
#
# ========== Epoch 720 ==========
# Train loss:  0.013484468725529063
# Accuracy:  0.92
#
# ========== Epoch 730 ==========
# Train loss:  0.013368756598945946
# Accuracy:  0.92
#
# ========== Epoch 740 ==========
# Train loss:  0.013256240315735874
# Accuracy:  0.92
#
# ========== Epoch 750 ==========
# Train loss:  0.013146794017746403
# Accuracy:  0.92
#
# ========== Epoch 760 ==========
# Train loss:  0.013040298318518965
# Accuracy:  0.92
#
# ========== Epoch 770 ==========
# Train loss:  0.012936639893335045
# Accuracy:  0.92
#
# ========== Epoch 780 ==========
# Train loss:  0.01283571110004167
# Accuracy:  0.92
#
# ========== Epoch 790 ==========
# Train loss:  0.012737409627925664
# Accuracy:  0.92
#
# ========== Epoch 800 ==========
# Train loss:  0.012641638172329422
# Accuracy:  0.92
#
# ========== Epoch 810 ==========
# Train loss:  0.012548304132796255
# Accuracy:  0.92
#
# ========== Epoch 820 ==========
# Train loss:  0.012457319332734838
# Accuracy:  0.92
#
# ========== Epoch 830 ==========
# Train loss:  0.012368599758943232
# Accuracy:  0.92
#
# ========== Epoch 840 ==========
# Train loss:  0.012282065319260536
# Accuracy:  0.92
#
# ========== Epoch 850 ==========
# Train loss:  0.012197639616993869
# Accuracy:  0.92
#
# ========== Epoch 860 ==========
# Train loss:  0.012115249740679963
# Accuracy:  0.92
#
# ========== Epoch 870 ==========
# Train loss:  0.012034826068054227
# Accuracy:  0.92
#
# ========== Epoch 880 ==========
# Train loss:  0.011956302083100381
# Accuracy:  0.92
#
# ========== Epoch 890 ==========
# Train loss:  0.011879614205147849
# Accuracy:  0.92
#
# ========== Epoch 900 ==========
# Train loss:  0.011804701629151293
# Accuracy:  0.92
#
# ========== Epoch 910 ==========
# Train loss:  0.011731506176239536
# Accuracy:  0.92
#
# ========== Epoch 920 ==========
# Train loss:  0.011659972153861333
# Accuracy:  0.92
#
# ========== Epoch 930 ==========
# Train loss:  0.011590046224721958
# Accuracy:  0.92
#
# ========== Epoch 940 ==========
# Train loss:  0.011521677283951835
# Accuracy:  0.92
#
# ========== Epoch 950 ==========
# Train loss:  0.011454816343843592
# Accuracy:  0.92
#
# ========== Epoch 960 ==========
# Train loss:  0.011389416425690127
# Accuracy:  0.92
#
# ========== Epoch 970 ==========
# Train loss:  0.011325432458153817
# Accuracy:  0.92
#
# ========== Epoch 980 ==========
# Train loss:  0.011262821181745247
# Accuracy:  0.92
# ========== Epoch 990 ==========
# Train loss:  0.011201541058984554
# Accuracy:  0.92
